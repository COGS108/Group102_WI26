# %% [markdown]
# ## Rubric
#
# Instructions: DELETE this cell before you submit via a `git push` to your repo before deadline. This cell is for your reference only and is not needed in your report.
#
#  Scoring: Out of 10 points
#
# - Each Developing  => -2 pts
# - Each Unsatisfactory/Missing => -4 pts
#   - until the score is 0
#
# If students address the detailed feedback in a future checkpoint they will earn these points back
#
#
#
#
#
#
# |                                  | **Unsatisfactory**                                                                                                                                                                                                                                                                                                                        | **Developing**                                                                                                                                                                                                       | **Proficient**                                                                                                                                                                                            | **Excellent**                                                                                                                                                                            |
# |----------------------------------|---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | **EDA relevance**                | EDA is mostly neither relevant to the question nor helpful in figuring out how to address the question. Or the EDA does address the question, but many obviously relevant variables / analyses / figures were not included. | EDA is partly irrelevant/unhelpful. EDA missed one or two obvioulsy relevant analysis (distributions of single variables or relationships between variables) | EDA includes the obviously relevant / helpful variables in addressing the question.                                                              | Thorough EDA fully explored the dataset                                                                                                                 |
# | **EDA analysis and description** | Many of the analyses are poor choices (e.g., using means instead of medians for obviously skewed data), or are poorly described in the text, or do not aid understanding the data                                                                                                                                                     | Some of the analyses are poor choices, or are poorly described in the text, or do not aid understanding the data                                                                                                 | All analyses are correct choices. Only one or two have minor issues in the text descriptions supporting them. Mostly they fit well with other elements of the EDA and support understanding the data  | All analyses are correct choices with clear text descriptions supporting them. The figures fit well with the other elements of the EDA, producing a clear understanding of the data. |
# | **EDA figures**                  | Many of the figures are poor plot choices (e.g., using a bar plot to represent a time series where it would be better to use a line plot) or have poor aesthetics (including colormap, data point shape/color, axis labels, titles, annotations, text legibility) or do not aid understanding the data                                | Some of the figures are poor plot choices or have poor aesthetics. Some figures do not aid understanding the data                                                                                                | All figures are correct plot choices. Only one or two have minor questionable aesthetic choices. The figures mostly fit well with the other elements of the EDA and support understanding the data    | All figures are correct plot choices with beautiful aesthetics. The figures fit well with the other elements of the EDA, producing a clear understanding of the data.                |

# %% [markdown]
# # COGS 108 - EDA Checkpoint

# %% [markdown]
# ## Authors
#
# Instructions: REPLACE the contents of this cell with your team list and their contributions. Note that this will change over the course of the checkpoints
#
# This is a modified [CRediT taxonomy of contributions](https://credit.niso.org). For each group member please list how they contributed to this project using these terms:
# > Analysis, Background research, Conceptualization, Data curation, Experimental investigation, Methodology, Project administration, Software, Visualization, Writing – original draft, Writing – review & editing
#
# Example team list and credits:
# - Alice Anderson: Conceptualization, Data curation, Methodology, Writing - original draft
# - Bob Barker:  Analysis, Software, Visualization
# - Charlie Chang: Project administration, Software, Writing - review & editing
# - Dani Delgado: Analysis, Background research, Visualization, Writing - original draft

# %% [markdown]
# ## Authors
#
# - Keilani Li: Data curation, Visualization, Software, Writing - original draft
# - Bryan Lu:
# - Hazel Liang: Analysis, Visualization, Writing-original draft
# - Lillian Tran:
# - Luis Quintanilla:

# %% [markdown]
# # Research Question

# %% [markdown]
# To what extent do headshot percentage and agent pick rates predict team win rates across regions in the 2024-2025 VCT playoffs, and does the strength of these predictors vary significantly between regions?
#
# We will approach our research question using variables such as agent pick rates, match results, region labels, and headshot percentages gathered from players who participated in VCT playoffs for both years.

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# ### Introduction
#
# Developed and released in 2020 by Riot Games, VALORANT is a free-to-play 5v5 tactical shooter game with 28 playable agents divided into 4 different roles–duelist, initiator, controller, sentinel–as of February 2026. Players select “agents” prior to the start of the match, with teams switching between attacking and defending “sites” halfway through the game. “Site” refers to an area on the map where the attacking team needs to plant the objective, otherwise known as the “spike,” and the defending team needs to prevent it from being planted or defuse it before it explodes after a certain amount of time. “Agents” are playable characters, each with unique abilities that complement the different roles:
# - Duelists: Excel at “entry fragging.” Basically, they are agents that are best known for initial fights and entering sites. Their abilities are often movement abilities or defensive utilities meant for getting kills to help their team enter the site and plant the bomb.
# - Initiators: Information gatherers. These agents' utilities help their team find where the enemies are positioning or even hiding. Additionally, their kit comes with abilities that help the team further fight enemies at an advantage, such as flashes or stuns. Flashing refers to blinding enemies, and stunning refers to a short debuff that impairs movement, gunfire rate, and shaky camera movement for the player to simulate dizziness. Both of these factors may increase a player’s probability of winning a gunfight with their opponent.
# - Controllers: Strategic agents that utilize their abilities to assist teammates and manipulate the battlefield, which involves the map, enemy positions, and actions. These abilities include walls and smokes, which help block out enemies and help their team take space on site. Walls and smokes are temporary barriers that block the enemy’s line of sight, but not a solid barrier, so they can still walk through them or enemies can also wait for them to disappear after a certain amount of time.
# - Sentinels: Site defenders and bombsite anchors. Sentinels are the agents who help secure the sites for their team. They excel at stalling enemy pushes–whether it be delaying an enemy attack from behind or delaying the enemy team from taking full control of a site.
#
# The goal of the game is to win 13 rounds by attacking and defending your site using gunplay and abilities. A core mechanic in gunplay is the headshot. While each gun deals a different amount of damage to the head, something unique to Valorant is that when both teams are on equal buy, meaning they have the same amount of money, most guns only require a single bullet to the head to instantly kill an opponent. This makes headshot percentage a key measurement of individual mechanical skill.
#
# VALORANT Champion Tour (VCT) is an annual tournament hosted by Riot Games. It features four regional leagues, Americas, EMEA, Pacific, and China. VCT events are divided into regional leagues and international leagues. Regional leagues refer to the four regions as mentioned previously while international leagues refer to Masters or Champions events. In other words, the international leagues consist of top teams that won their regional games and the one team that wins is considered the best team in the world as of that year. Since there are many different levels of tournaments and stages, for this project, we will be focusing on VCT Challengers playoff games from 2024-2025. We decided to leave out games from previous stages since the playoffs stage involves top teams, where winners advance to the grand finals.
#
# From a viewer's perspective, each region has different play styles. Regions like EMEA may play very strategically while other regions like to ‘run it down,’ or in other words, play more aggressively. With 18 unique guns to buy from and 28 different agents to choose from, we thought it would be interesting to explore how headshot rates and agent pick rates affect win percentages across different regions.
#
# This research matters because VCT playoffs represent the highest level of competitive Valorant. The prize pools for these international events exceed a million dollars annually. With any kind of sport, successful teams will attract huge sponsorship deals and brand partners. Understanding certain features that establish a successful team can help improve future games and coaching decisions. It might even shine light on any adjustments necessary for improving game balance by showing us whether certain playstyles or agents have a possible disproportionate competitive advantage. In addition, regional playstyle differences may reveal how gameplay is tied to cultural differences and practice environments.
#
# ### Prior Work
#
# One study that has been done related to our topic is Valorant Analysis: A Comparative Study of Machine Learning Models<a name="cite_ref-1"></a>[<sup>1</sup>](#cite_note-1). As suggested by the title, the author compared the performances between different machine learning models trained on Valorant data. More specifically, they compared these models to determine which is the best at revealing underlying patterns and predicting outcomes in a "high-stakes gaming environment." The author used a Kaggle dataset on a player's first 1000 Valorant games (not their own games). They performed basic EDA and created data visualizations to understand visual patterns across different variables like agent pick distributions, rank distribution, map frequency, wins/losses, and KDA (kills, deaths, assists) metrics. Afterwards, they trained an XGB (eXtreme Gradient Boosting) model and an RF (Random Forest) model. When comparing metrics&mdash;accuracy, precision, recall, F1-score, class 0 performance, weight average&mdash;between the two models, they found that the RF model performed slightly better in terms of precision and F1-score.
#
# Another study, titled Valorant VCT Challengers 2024 Analysis, has actually been done on a dataset we may consider using<a name="cite_ref-2"></a>[<sup>2</sup>](#cite_note-2). The author first preprocessed the data by renaming columns, converting data types, and handling missing values. Going into EDA, they looked into region and agent distribution, and then they visualized selected columns as a density histogram. Afterward, they looked into the top 1% of players with the highest rating in the tournament and top 1% of agents played.
#
# The last study we were able to find related to our topic is the VCT 2024 Agent Composition Analysis<a name="cite_ref-3"></a>[<sup>3</sup>](#cite_note-3). This analysis has also been done on a different dataset we consider using for this project. The author preprocessed their data through feature engineering, renaming columns, and did some basic exploration where they looked at descriptive summary statistics for: number of matches played per tournament, stage distribution, match type distribution, and number of matches played per map. They also visualized win rates between agent picks, maps, and they applied a regression model to see if meta agent picks have an impact on win probability and a prediction model on whether map and agent pick influences win probability. Lastly, they created a recommendation list of agents based on win rate and pick rate for each map, which was very interesting to look at.
#
# Each of the three studies mentioned above explores individual performance and agent compositions separately. None have examined how the interactions between mechanical skill (headshot percentage) and strategic choices (agent compositions) vary across the different regions in VCT. Additionally, the existing studies primarily focus on descriptive analysis rather than predictive modeling and do not specifically analyze any regional playstyle differences. Our project differs from other studies as it:
# 1. Examines the interaction between headshot percentage and agent picks
# 2. Compares how results vary across the four major VCT regions and to what extent
# 3. Uses playoff data from two consecutive years
#
# A limitation we found from the first prior work is related to the dataset they used for analysis. From Kaggle, they used a dataset titled My First 1000 Valorant Games, where the dataset author used the data gathered from their own account. With that said, the analyses that were done in the article are not generalizable to the Valorant population as the machine learning models were applied to analyze one player’s account out of millions of others. They also did not explain how their findings were important and focused more on how the models they used differed from one another in terms of metrics. It was also a bit unclear what variables were being used as inputs for the machine learning, especially more so if you do not know how to read code. We will address this kind of limitation by being clear about information that might be missing from our dataset and how they affect our conclusion findings, and also creating markdown cells to explain our work in detail so our reader does not feel lost.
#
# Another limitation can be found in the second prior work, where their data visualization in comparing 4 different columns–rating, KAST (kills, assists, survived, traded), headshot percentage, clutch success percentage–overlaps one another. This makes the graph hard for the reader to interpret even when there’s a short caption explaining all but one plot appears normally distributed. We would address this type of limitation in our project by making sure our plots are easily understandable and so we can reduce cognitive overload.
#
# The last limitation we found is in the third study, which also relates to some of their data visualizations. For example, when looking into the win rates per agent, the author chose to give their bar graph a diverging color scheme when it is unnecessary. This is considered a limitation because it may contribute to cognitive overload since the colors do not provide any significant meaning. The interpretation of the graph would be the same if all the bars were one single color. This color scheme is more suited for visualizations such as a correlation heatmap, which is a graph they do have in their study. But for a bar graph, a diverging color scheme is not needed. We will address this type of limitation in our project by using colors wisely in our data visualizations especially if it can help convey more information to our audience.
#
# ### References
#
# 1. <a name="cite_note-1"></a> [^](#cite_ref-1) https://medium.com/@sanketangchekar/valorant-analysis-a-comparative-study-of-machine-learning-models-fa3f2866335e
# 2. <a name="cite_note-2"></a> [^](#cite_ref-2) https://www.kaggle.com/code/blackdragonk333/valorant-vct-challengers-2024-analysis-eda
# 3. <a name="cite_note-3"></a> [^](#cite_ref-3) https://www.kaggle.com/code/setsuna00/vct-2024-agent-composition-analysis

# %% [markdown]
# # Hypothesis

# %% [markdown]
# We hypothesize that while headshot percentage positively correlates with win rates across all regions, the strength of this relationship will vary across different regions and their playstyles. We further hypothesize that agent pick rates moderate this relationship, such that utility-heavy compositions reduce the marginal impact of headshot percentage on team win rates.
#
# As mentioned in our background, each of the four regions has different play styles. Our hypothesis is that regions that favor utility-reliant agents (such as EMEA) may show a weaker headshot-win rate correlation compared to regions that play more duelist-heavy “run it down” compositions. Although headshot percentage can be an indicator of a winning team, utility-heavy compositions can also garner kills without relying solely on raw aim, potentially mitigating the impact of headshot percentage differences.

# %% [markdown]
# ## Data

# %% [markdown]
# ### Data overview
#
# Instructions: REPLACE the contents of this cell with descriptions of your actual datasets.
#
# For each dataset include the following information
# - Dataset #1
#   - Dataset Name: Valorant Champion Tour 2021-2025
#   - Link to the dataset: https://www.kaggle.com/datasets/ryanluong1/valorant-champion-tour-2021-2023-data?select=vct_2025
#   - Number of observations: 373,564 (prior to cleaning)
#   - Number of variables: 46
#   - Description of the variables most relevant to this project
#     - ``headshot_percentage``
#     - ``pick rate``
#     - ``agent``
#     - ``map``
#     - ``outcome``
#     - ``match_result``
#   - Descriptions of any shortcomings this dataset has with respect to the project
#     - Missing data due to uncontrollable factors, such as missing names and certain situations not occurring (e.g, 1v1 gunfights or operator kills)
# - Dataset #2
#   - Dataset Name: Valorant Champions Tour 2024
#   - Link to the dataset: https://www.kaggle.com/datasets/sauurabhkr/valorant-champions-tour-2024
#   - Number of observations: 3123 (when combining all files together),
#   - Number of variables: 7
#   - Description of the variables most relevant to this project
#     - ``region``
#       - the region the player represents (e.g 'Americas')
#     - ``headshot_percentage``
#       - percentage of kills by headshots (e.g '26%')
#     - ``agent``
#       - list of agents the player normally uses
#     - ``playerCategory``
#       - competitive level tier (VCT International, VCT Challengers, or VCT Game Changers)
#     - ``team``
#       - the player's team affiliation (e.g 'SEN' for Sentinels)
#   - Descriptions of any shortcomings this dataset has with respect to the project
#     - This dataset does not provide data on whether the team wins or loses a match, so we would not be able to look into how the variables we want to measure (headshot percentage and agent pick rate) affects win percentage.
# - Dataset #3
#   - Dataset Name: Valorant VCT Champions 2025 Dataset
#   - Link to the dataset: https://www.kaggle.com/datasets/kierru/valorant-vct-champions-2025-dataset
#   - Number of observations: 1760
#   - Number of variables: 22
#   - Description of the variables most relevant to this project
#     - ``rating``
#     - ``kill/death ratio (K/D)``
#     - ``KAST``
#     - ``headshot percentage``
#   - Descriptions of any shortcomings this dataset has with respect to the project
#     - Only includes players in the playoffs stage
#     - Team-wide data might hinder individual contributions
#
#     This dataset includes statistics for both matches and players from the Valorant Champions Tour (VCT) in 2025.

# %%
# Run this code every time when you're actively developing modules in .py files.  It's not needed if you aren't making modules
#
## this code is necessary for making sure that any modules we load are updated here 
## when their source code .py files are modified

# %load_ext autoreload
# %autoreload 2

# %%
# Setup code -- Run only once after cloning!!! 
#
# this code downloads the data from its source to the `data/00-raw/` directory
# if the data hasn't updated you don't need to do this again!

# if you don't already have these packages (you should!) uncomment this line
# %pip install requests tqdm

# import sys
# sys.path.append('./modules') # this tells python where to look for modules to import

# import get_data # this is where we get the function we need to download data

# # replace the urls and filenames in this list with your actual datafiles
# # yes you can use Google drive share links or whatever
# # format is a list of dictionaries; 
# # each dict has keys of 
# #   'url' where the resource is located
# #   'filename' for the local filename where it will be stored 
# datafiles = [
#     { 'url': 'https://raw.githubusercontent.com/fivethirtyeight/data/refs/heads/master/airline-safety/airline-safety.csv', 'filename':'airline-safety.csv'},
#     { 'url': 'https://raw.githubusercontent.com/fivethirtyeight/data/refs/heads/master/bad-drivers/bad-drivers.csv', 'filename':'bad-drivers.csv'}
# ]

# get_data.get_raw(datafiles,destination_directory='data/00-raw/')

# %% [markdown]
# ### Exploring: Valorant Champion Tour 2021-2025 data
#
# This dataset includes statistics for both matches and players from the Valorant Champions Tour (VCT) between 2021 and 2025, but the focus is on the 2024 VCT.
#
# Key variables from this dataset are ``pick rate``, ``headshot_percentage``, ``agent``, ``map``, ``outcome``, and ``match_result``. Pick rate is a strong indicator of an agent’s popularity among Valorant players. While it may not automatically mean a higher win rate, it can indicate a comfort pick for certain players since teams have preferences for their desired agents over others. It is also significant to note which side an agent is on because that can determine when specific agents are better used. Headshot percentage is a key stat to analyze with context, as some agents are better utilized for attack compared to defense and vice versa. Thus, the outcome can be explained as to why headshot percentages are higher for agents on a particular side. The map provides information on the kind of battlefield used for every match in the dataset. Knowing the names of the agents is crucial for understanding the value they bring to the battlefield. This ties to the pick rates because different playstyles fit each agent. Lastly, variables related to match wins, such as ``outcome`` and ``match_result``, are the most important statistics for our project since they are connected to whether teams win/lose rounds and ultimately the game as a whole.
#
# From reading the data shown on this dataset, it is important to note the key limitations that this dataset presents. The first concern to address is the missing stats from matches played in China. This can be attributed to Chinese-hosted events not having APIs (Application Programming Interface) available for post-game statistics. Thus, multiple variables from Chinese-hosted events are missing and cannot be used for analysis. However, there are still missing values even when events are not hosted in China. This may be due to how events play out during the game. For example, null values may appear in a “2k” column, representing a player getting 2 kills, because it is possible for that player to not get 2 kills in one round. Another instance may include null values for “Overtime Scores” because it is possible for a match to not go into overtime. To go into overtime in Valorant means that the score is 12-12 and one team must win 2 consecutive rounds in a row in order to win (e.g a team will win the entire game if the match score is 14-12).

# %% [markdown]
# #### Importing & cleaning
#
# Before we start exploring each csv file from the 2024 and 2025 folders of this dataset, it's important to clarify which datasets ***have*** been loaded and which ***have not***.
#
# From each folder except for ``matches``, we have loaded every csv file into our project. We have not loaded the following datasets from ``matches`` with the respective reasons:
# - ``draft_phase.csv``
#     - This csv file contains information on map picks and bans prior to the match. Before every match, both teams alternate on banning maps from the competitive map pool until there are two maps left. Since our research question does not require us to look into map picks, we do not need to use this dataset.
# - ``kills_stats.csv``
#     - This csv file contrains information on overall kills for each player. Information such as agents played, number of "2k," "3k," etc., and econ score can be found here, but we do not need this information as other files can provide more details.
# - ``kills.csv``
#     - This csv file contains information on kills between players. More specifically, gunfights between two players regarding how many kills they have on each other and the difference in kills. Since we are not focusing on individual player performance, we do not need to use this dataset.
# - ``maps_played.csv``
#     - This csv file contains information on which maps have been played for each match. Similar to ``draft_phase.csv``, we do not need to use this dataset since we are not focusing on map information.
# - ``maps_scores.csv``
#     - This csv file contains information on the overall match score for each team and how many rounds have been played in overtime. We do not need to use this dataset since our research question does not need score information.
# - ``rounds_kills.csv``
#     - This csv file contrains information on kills between players for each player for each round of a match. It is formatted similarly to ``kills.csv`` and therefore we do not need this dataset since we are not trying to compare individual kills between teams.

# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### VCT 2024 Folder Exploration

# %%
# vct 2024 folder

## agents folder
vct24_agents_pick = pd.read_csv('data/00-raw/vct_both_2024_2025/vct_2024/agents/agents_pick_rates.csv')
vct24_maps_stats = pd.read_csv('data/00-raw/vct_both_2024_2025/vct_2024/agents/maps_stats.csv')
vct24_teams_pick = pd.read_csv('data/00-raw/vct_both_2024_2025/vct_2024/agents/teams_picked_agents.csv')

## ids folder
vct24_players_ids = pd.read_csv('data/00-raw/vct_both_2024_2025/vct_2024/ids/players_ids.csv')
vct24_teams_ids = pd.read_csv('data/00-raw/vct_both_2024_2025/vct_2024/ids/teams_ids.csv')
vct24_tournaments_types = pd.read_csv('data/00-raw/vct_both_2024_2025/vct_2024/ids/tournaments_stages_match_types_ids.csv')
vct24_tournaments_games = pd.read_csv('data/00-raw/vct_both_2024_2025/vct_2024/ids/tournaments_stages_matches_games_ids.csv')

## matches folder
# vct24_draft_phase = pd.read_csv('data/00-raw/vct_both_2024_2025/vct_2024/matches/draft_phase.csv')

vct24_eco_rounds = pd.read_csv('data/00-raw/vct_both_2024_2025/vct_2024/matches/eco_rounds.csv')
vct24_eco_stats = pd.read_csv('data/00-raw/vct_both_2024_2025/vct_2024/matches/eco_stats.csv')

# vct24_kills_stats = pd.read_csv('data/00-raw/vct_both_2024_2025/vct_2024/matches/kills_stats.csv')
# vct24_kills = pd.read_csv('data/00-raw/vct_both_2024_2025/vct_2024/matches/kills.csv')

# vct24_maps_played = pd.read_csv('data/00-raw/vct_both_2024_2025/vct_2024/matches/maps_played.csv')
# vct24_maps_scores = pd.read_csv('data/00-raw/vct_both_2024_2025/vct_2024/matches/maps_scores.csv')
vct24_overview = pd.read_csv('data/00-raw/vct_both_2024_2025/vct_2024/matches/overview.csv')
# vct24_rounds_kills = pd.read_csv('data/00-raw/vct_both_2024_2025/vct_2024/matches/rounds_kills.csv')
vct24_scores = pd.read_csv('data/00-raw/vct_both_2024_2025/vct_2024/matches/scores.csv')
vct24_team_mapping = pd.read_csv('data/00-raw/vct_both_2024_2025/vct_2024/matches/team_mapping.csv')

vct24_winloss_count = pd.read_csv('data/00-raw/vct_both_2024_2025/vct_2024/matches/win_loss_methods_count.csv')
vct24_winloss_round = pd.read_csv('data/00-raw/vct_both_2024_2025/vct_2024/matches/win_loss_methods_round_number.csv')

## players_stats folder
vct24_players_stats = pd.read_csv('data/00-raw/vct_both_2024_2025/vct_2024/players_stats/players_stats.csv')

# %%
print(vct24_agents_pick.shape)
vct24_agents_pick.head()
# Out:
# (24840, 6)
#                 Tournament     Stage           Match Type       Map    Agent  \
# 0  Valorant Champions 2024  Playoffs  Upper Quarterfinals  All Maps     sova
# 1  Valorant Champions 2024  Playoffs  Upper Quarterfinals  All Maps   cypher
# 2  Valorant Champions 2024  Playoffs  Upper Quarterfinals  All Maps     omen
# 3  Valorant Champions 2024  Playoffs  Upper Quarterfinals  All Maps    viper
# 4  Valorant Champions 2024  Playoffs  Upper Quarterfinals  All Maps  killjoy
#
#   Pick Rate
# 0       69%
# 1       56%
# 2       56%
# 3       44%
# 4       38%

# %%
print(vct24_maps_stats.shape)
vct24_maps_stats.head()
# Out:
# (1035, 7)
#                 Tournament     Stage           Match Type       Map  \
# 0  Valorant Champions 2024  Playoffs  Upper Quarterfinals  All Maps
# 1  Valorant Champions 2024  Playoffs  Upper Quarterfinals    Sunset
# 2  Valorant Champions 2024  Playoffs  Upper Quarterfinals     Abyss
# 3  Valorant Champions 2024  Playoffs  Upper Quarterfinals      Bind
# 4  Valorant Champions 2024  Playoffs  Upper Quarterfinals     Haven
#
#    Total Maps Played Attacker Side Win Percentage Defender Side Win Percentage
# 0                  8                          53%                          47%
# 1                  2                          36%                          64%
# 2                  2                          64%                          36%
# 3                  1                          75%                          25%
# 4                  1                          38%                          62%

# %%
print(vct24_teams_pick.shape)
vct24_teams_pick.head()
# Out:
# (15647, 9)
#                 Tournament     Stage           Match Type     Map Team  \
# 0  Valorant Champions 2024  Playoffs  Upper Quarterfinals  Sunset  DRX
# 1  Valorant Champions 2024  Playoffs  Upper Quarterfinals  Sunset  DRX
# 2  Valorant Champions 2024  Playoffs  Upper Quarterfinals  Sunset  DRX
# 3  Valorant Champions 2024  Playoffs  Upper Quarterfinals  Sunset  DRX
# 4  Valorant Champions 2024  Playoffs  Upper Quarterfinals  Sunset  DRX
#
#     Agent  Total Wins By Map  Total Loss By Map  Total Maps Played
# 0    sova                  0                  1                  1
# 1  cypher                  0                  1                  1
# 2    omen                  0                  1                  1
# 3  breach                  0                  1                  1
# 4    neon                  0                  1                  1

# %%
print(vct24_players_ids.shape)
vct24_players_ids.head()
# Out:
# (260, 2)
#      Player  Player ID
# 0   t3xture       9196
# 1    Meteor      13039
# 2     Lakia        773
# 3     Karon      34974
# 4  Munchkin       2489

# %%
print(vct24_teams_ids.shape)
vct24_teams_ids.head()
# Out:
# (44, 2)
#               Team  Team ID
# 0            Gen.G       17
# 1        Sentinels        2
# 2  FunPlus Phoenix    11328
# 3    Team Heretics     1001
# 4              DRX     8185

# %%
print(vct24_tournaments_types.shape)
vct24_tournaments_types.head()
# Out:
# (197, 6)
#                 Tournament  Tournament ID     Stage  Stage ID  \
# 0  Valorant Champions 2024           2097  Playoffs    4131.0
# 1  Valorant Champions 2024           2097  Playoffs    4131.0
# 2  Valorant Champions 2024           2097  Playoffs    4131.0
# 3  Valorant Champions 2024           2097  Playoffs    4131.0
# 4  Valorant Champions 2024           2097  Playoffs    4131.0
#
#             Match Type  Match Type ID
# 0  Upper Quarterfinals        26235.0
# 1     Upper Semifinals        26236.0
# 2          Upper Final        26237.0
# 3          Grand Final        26238.0
# 4        Lower Round 1        26239.0

# %%
print(vct24_tournaments_games.shape)
vct24_tournaments_games.head()
# Out:
# (1104, 9)
#                 Tournament  Tournament ID        Stage  Stage ID   Match Type  \
# 0  Valorant Champions 2024           2097  Group Stage      4035  Opening (B)
# 1  Valorant Champions 2024           2097  Group Stage      4035  Opening (B)
# 2  Valorant Champions 2024           2097  Group Stage      4035  Opening (B)
# 3  Valorant Champions 2024           2097  Group Stage      4035  Opening (B)
# 4  Valorant Champions 2024           2097  Group Stage      4035  Opening (B)
#
#                          Match Name  Match ID     Map  Game ID
# 0                Gen.G vs Sentinels    378662   Haven   180369
# 1                Gen.G vs Sentinels    378662  Ascent   180370
# 2  FunPlus Phoenix vs Team Heretics    378663   Abyss   180372
# 3  FunPlus Phoenix vs Team Heretics    378663    Bind   180373
# 4  FunPlus Phoenix vs Team Heretics    378663   Lotus   180374

# %%
print(vct24_eco_rounds.shape)
vct24_eco_rounds.head()
# Out:
# (34514, 11)
#                 Tournament        Stage   Match Type          Match Name  \
# 0  Valorant Champions 2024  Group Stage  Opening (B)  Gen.G vs Sentinels
# 1  Valorant Champions 2024  Group Stage  Opening (B)  Gen.G vs Sentinels
# 2  Valorant Champions 2024  Group Stage  Opening (B)  Gen.G vs Sentinels
# 3  Valorant Champions 2024  Group Stage  Opening (B)  Gen.G vs Sentinels
# 4  Valorant Champions 2024  Group Stage  Opening (B)  Gen.G vs Sentinels
#
#      Map  Round Number       Team Loadout Value Remaining Credits  \
# 0  Haven             1      Gen.G          3.9k              0.3k
# 1  Haven             1  Sentinels          3.8k              0.2k
# 2  Haven             2      Gen.G         14.5k              2.4k
# 3  Haven             2  Sentinels          3.4k              9.0k
# 4  Haven             3      Gen.G         15.3k             11.7k
#
#                Type Outcome
# 0         Eco: 0-5k     Win
# 1         Eco: 0-5k    Loss
# 2  Semi-buy: 10-20k     Win
# 3         Eco: 0-5k    Loss
# 4  Semi-buy: 10-20k    Loss

# %%
print(vct24_eco_stats.shape)
vct24_eco_stats.head()
# Out:
# (11350, 9)
#                 Tournament        Stage   Match Type          Match Name  \
# 0  Valorant Champions 2024  Group Stage  Opening (B)  Gen.G vs Sentinels
# 1  Valorant Champions 2024  Group Stage  Opening (B)  Gen.G vs Sentinels
# 2  Valorant Champions 2024  Group Stage  Opening (B)  Gen.G vs Sentinels
# 3  Valorant Champions 2024  Group Stage  Opening (B)  Gen.G vs Sentinels
# 4  Valorant Champions 2024  Group Stage  Opening (B)  Gen.G vs Sentinels
#
#      Map   Team        Type  Initiated  Won
# 0  Haven  Gen.G  Pistol Won        NaN    2
# 1  Haven  Gen.G   Eco (won)        2.0    2
# 2  Haven  Gen.G     $ (won)        1.0    0
# 3  Haven  Gen.G    $$ (won)        6.0    4
# 4  Haven  Gen.G   $$$ (won)       12.0    7

# %%
print(vct24_overview.shape)
vct24_overview.head()
# Out:
# (46152, 21)
#                 Tournament        Stage   Match Type          Match Name  \
# 0  Valorant Champions 2024  Group Stage  Opening (B)  Gen.G vs Sentinels
# 1  Valorant Champions 2024  Group Stage  Opening (B)  Gen.G vs Sentinels
# 2  Valorant Champions 2024  Group Stage  Opening (B)  Gen.G vs Sentinels
# 3  Valorant Champions 2024  Group Stage  Opening (B)  Gen.G vs Sentinels
# 4  Valorant Champions 2024  Group Stage  Opening (B)  Gen.G vs Sentinels
#
#      Map   Player   Team   Agents  Rating  Average Combat Score  ...  Deaths  \
# 0  Haven  t3xture  Gen.G     jett    1.60                 305.0  ...    12.0
# 1  Haven  t3xture  Gen.G     jett    1.71                 364.0  ...     5.0
# 2  Haven  t3xture  Gen.G     jett    1.52                 261.0  ...     7.0
# 3  Haven   Meteor  Gen.G  killjoy    1.23                 221.0  ...    10.0
# 4  Haven   Meteor  Gen.G  killjoy    1.16                 229.0  ...     4.0
#
#    Assists  Kills - Deaths (KD)  Kill, Assist, Trade, Survive %  \
# 0      4.0                 12.0                             81%
# 1      2.0                  7.0                             89%
# 2      2.0                  5.0                             75%
# 3      4.0                  7.0                             76%
# 4      1.0                  4.0                             78%
#
#   Average Damage Per Round  Headshot % First Kills  First Deaths  \
# 0                    188.0         31%         3.0           4.0
# 1                    216.0         37%         2.0           2.0
# 2                    168.0         24%         1.0           2.0
# 3                    140.0         26%         1.0           4.0
# 4                    127.0         35%         1.0           1.0
#
#    Kills - Deaths (FKD)    Side
# 0                  -1.0    both
# 1                   0.0  attack
# 2                  -1.0  defend
# 3                  -3.0    both
# 4                   0.0  attack
#
# [5 rows x 21 columns]

# %%
print(vct24_scores.shape)
vct24_scores.head()
# Out:
# (434, 9)
#                 Tournament        Stage   Match Type  \
# 0  Valorant Champions 2024  Group Stage  Opening (B)
# 1  Valorant Champions 2024  Group Stage  Opening (B)
# 2  Valorant Champions 2024  Group Stage  Opening (A)
# 3  Valorant Champions 2024  Group Stage  Opening (A)
# 4  Valorant Champions 2024  Group Stage  Opening (C)
#
#                          Match Name           Team A           Team B  \
# 0                Gen.G vs Sentinels            Gen.G        Sentinels
# 1  FunPlus Phoenix vs Team Heretics  FunPlus Phoenix    Team Heretics
# 2                DRX vs KRÜ Esports              DRX      KRÜ Esports
# 3         FNATIC vs Bilibili Gaming           FNATIC  Bilibili Gaming
# 4         LEVIATÁN vs Talon Esports         LEVIATÁN    Talon Esports
#
#    Team A Score  Team B Score       Match Result
# 0             2             0          Gen.G won
# 1             1             2  Team Heretics won
# 2             2             1            DRX won
# 3             2             0         FNATIC won
# 4             2             0       LEVIATÁN won

# %%
print(vct24_team_mapping.shape)
vct24_team_mapping.head()
# Out:
# (44, 2)
#   Abbreviated        Full Name
# 0         GEN            Gen.G
# 1         SEN        Sentinels
# 2         FPX  FunPlus Phoenix
# 3          TH    Team Heretics
# 4         DRX              DRX

# %%
print(vct24_winloss_count.shape)
vct24_winloss_count.head()
# Out:
# (2208, 14)
#                 Tournament        Stage   Match Type  \
# 0  Valorant Champions 2024  Group Stage  Opening (B)
# 1  Valorant Champions 2024  Group Stage  Opening (B)
# 2  Valorant Champions 2024  Group Stage  Opening (B)
# 3  Valorant Champions 2024  Group Stage  Opening (B)
# 4  Valorant Champions 2024  Group Stage  Opening (B)
#
#                          Match Name     Map             Team  Elimination  \
# 0                Gen.G vs Sentinels   Haven            Gen.G            7
# 1                Gen.G vs Sentinels   Haven        Sentinels            3
# 2                Gen.G vs Sentinels  Ascent            Gen.G            9
# 3                Gen.G vs Sentinels  Ascent        Sentinels            5
# 4  FunPlus Phoenix vs Team Heretics   Abyss  FunPlus Phoenix           10
#
#    Detonated  Defused  Time Expiry (No Plant)  Eliminated  Defused Failed  \
# 0          1        4                       1           3               2
# 1          2        3                       0           7               1
# 2          4        0                       0           5               0
# 3          0        2                       0           9               4
# 4          0        2                       0           9               2
#
#    Detonation Denied  Time Expiry (Failed to Plant)
# 0                  3                              0
# 1                  4                              1
# 2                  2                              0
# 3                  0                              0
# 4                  3                              0

# %%
print(vct24_winloss_round.shape)
vct24_winloss_round.head()
# Out:
# (46754, 9)
#                 Tournament        Stage   Match Type          Match Name  \
# 0  Valorant Champions 2024  Group Stage  Opening (B)  Gen.G vs Sentinels
# 1  Valorant Champions 2024  Group Stage  Opening (B)  Gen.G vs Sentinels
# 2  Valorant Champions 2024  Group Stage  Opening (B)  Gen.G vs Sentinels
# 3  Valorant Champions 2024  Group Stage  Opening (B)  Gen.G vs Sentinels
# 4  Valorant Champions 2024  Group Stage  Opening (B)  Gen.G vs Sentinels
#
#      Map  Round Number       Team            Method Outcome
# 0  Haven             1      Gen.G           Defused     Win
# 1  Haven             1  Sentinels  Detonated Denied    Loss
# 2  Haven             2      Gen.G       Elimination     Win
# 3  Haven             2  Sentinels        Eliminated    Loss
# 4  Haven             3  Sentinels       Elimination     Win

# %%
print(vct24_players_stats.shape)
vct24_players_stats.head()
# Out:
# (15030, 25)
#                 Tournament     Stage           Match Type      Player  \
# 0  Valorant Champions 2024  Playoffs  Upper Quarterfinals         Boo
# 1  Valorant Champions 2024  Playoffs  Upper Quarterfinals         Boo
# 2  Valorant Champions 2024  Playoffs  Upper Quarterfinals         Boo
# 3  Valorant Champions 2024  Playoffs  Upper Quarterfinals  benjyfishy
# 4  Valorant Champions 2024  Playoffs  Upper Quarterfinals  benjyfishy
#
#            Teams       Agents  Rounds Played  Rating  Average Combat Score  \
# 0  Team Heretics        astra             26    0.75                   138
# 1  Team Heretics         fade             16    1.10                   185
# 2  Team Heretics  astra, fade             42    0.88                   162
# 3  Team Heretics       cypher             26    0.85                   203
# 4  Team Heretics      killjoy             16    1.36                   169
#
#    Kills:Deaths  ... First Deaths Per Round  Headshot %  Clutch Success %  \
# 0          0.58  ...                   0.08         21%               22%
# 1          1.38  ...                   0.00         21%               NaN
# 2          0.81  ...                   0.05         21%               22%
# 3          0.86  ...                   0.15         34%               NaN
# 4          2.40  ...                   0.00         28%               50%
#
#    Clutches (won/played)  Maximum Kills in a Single Map  Kills Deaths Assists  \
# 0                    2/9                             11     11     19      14
# 1                    NaN                             11     11      8       3
# 2                    2/9                             11     22     27      17
# 3                    NaN                             18     18     21       3
# 4                    1/2                             12     12      5       2
#
#   First Kills  First Deaths
# 0           1             2
# 1           2             0
# 2           3             2
# 3           2             4
# 4           1             0
#
# [5 rows x 25 columns]

# %%
vct24_agents_pick.isna().sum()
# Out:
# Tournament    0
# Stage         0
# Match Type    0
# Map           0
# Agent         0
# Pick Rate     0
# dtype: int64

# %%
# save the data in 02-processed
vct24_agents_pick_clean = vct24_agents_pick.copy()

vct24_agents_pick_clean.to_csv(
    "data/02-processed/vct_both_2024_2025/vct_2024/agents_pick.csv",
    index=False
)

# %%
vct24_maps_stats.isna().sum()
# Out:
# Tournament                      0
# Stage                           0
# Match Type                      0
# Map                             0
# Total Maps Played               0
# Attacker Side Win Percentage    0
# Defender Side Win Percentage    0
# dtype: int64

# %%
vct24_teams_pick.isna().sum()
# Out:
# Tournament           0
# Stage                0
# Match Type           0
# Map                  0
# Team                 0
# Agent                0
# Total Wins By Map    0
# Total Loss By Map    0
# Total Maps Played    0
# dtype: int64

# %%
vct24_players_ids.isna().sum()
# Out:
# Player       0
# Player ID    0
# dtype: int64

# %%
vct24_teams_ids.isna().sum()
# Out:
# Team       0
# Team ID    0
# dtype: int64

# %%
vct24_tournaments_types.isna().sum()
# Out:
# Tournament        0
# Tournament ID     0
# Stage             0
# Stage ID         15
# Match Type        0
# Match Type ID    15
# dtype: int64

# %%
# look into missing entries
vct24_tournaments_types[
    vct24_tournaments_types["Stage ID"].isna() |
    vct24_tournaments_types["Match Type ID"].isna()
]
# Out:
#                                 Tournament  Tournament ID       Stage  \
# 24                 Valorant Champions 2024           2097  All Stages
# 35      Champions Tour 2024: China Stage 2           2096  All Stages
# 46       Champions Tour 2024: EMEA Stage 2           2094  All Stages
# 57   Champions Tour 2024: Americas Stage 2           2095  All Stages
# 68    Champions Tour 2024: Pacific Stage 2           2005  All Stages
# 80   Champions Tour 2024: Masters Shanghai           1999  All Stages
# 91    Champions Tour 2024: Pacific Stage 1           2002  All Stages
# 103     Champions Tour 2024: China Stage 1           2006  All Stages
# 115      Champions Tour 2024: EMEA Stage 1           1998  All Stages
# 127  Champions Tour 2024: Americas Stage 1           2004  All Stages
# 136    Champions Tour 2024: Masters Madrid           1921  All Stages
# 151  Champions Tour 2024: Americas Kickoff           1923  All Stages
# 166     Champions Tour 2024: China Kickoff           1926  All Stages
# 181      Champions Tour 2024: EMEA Kickoff           1925  All Stages
# 196   Champions Tour 2024: Pacific Kickoff           1924  All Stages
#
#      Stage ID       Match Type  Match Type ID
# 24        NaN  All Match Types            NaN
# 35        NaN  All Match Types            NaN
# 46        NaN  All Match Types            NaN
# 57        NaN  All Match Types            NaN
# 68        NaN  All Match Types            NaN
# 80        NaN  All Match Types            NaN
# 91        NaN  All Match Types            NaN
# 103       NaN  All Match Types            NaN
# 115       NaN  All Match Types            NaN
# 127       NaN  All Match Types            NaN
# 136       NaN  All Match Types            NaN
# 151       NaN  All Match Types            NaN
# 166       NaN  All Match Types            NaN
# 181       NaN  All Match Types            NaN
# 196       NaN  All Match Types            NaN

# %%
## missing values are expected, so no rows are dropped and no imputation is performed
vct24_tournaments_types_cleaned = vct24_tournaments_types.copy()

## verify cleaned dataset
print(vct24_tournaments_types_cleaned.shape)

# save the data in data/02-processed
vct24_tournaments_types_cleaned.to_csv(
    "data/02-processed/vct_both_2024_2025/vct_2024/tournaments_stages_match_types_ids.csv",
    index=False
)
# Out:
# (197, 6)

# %%
vct24_tournaments_games.isna().sum()
# Out:
# Tournament       0
# Tournament ID    0
# Stage            0
# Stage ID         0
# Match Type       0
# Match Name       0
# Match ID         0
# Map              0
# Game ID          0
# dtype: int64

# %%
vct24_eco_rounds.isna().sum()
# Out:
# Tournament           0
# Stage                0
# Match Type           0
# Match Name           0
# Map                  0
# Round Number         0
# Team                 0
# Loadout Value        0
# Remaining Credits    0
# Type                 0
# Outcome              0
# dtype: int64

# %%
vct24_eco_stats.isna().sum()
# Out:
# Tournament       0
# Stage            0
# Match Type       0
# Match Name       0
# Map              0
# Team             0
# Type             0
# Initiated     2270
# Won              0
# dtype: int64

# %%
# look into missing entries
vct24_eco_stats[vct24_eco_stats['Initiated'].isna()].head()
# Out:
#                  Tournament        Stage   Match Type          Match Name  \
# 0   Valorant Champions 2024  Group Stage  Opening (B)  Gen.G vs Sentinels
# 5   Valorant Champions 2024  Group Stage  Opening (B)  Gen.G vs Sentinels
# 10  Valorant Champions 2024  Group Stage  Opening (B)  Gen.G vs Sentinels
# 15  Valorant Champions 2024  Group Stage  Opening (B)  Gen.G vs Sentinels
# 20  Valorant Champions 2024  Group Stage  Opening (B)  Gen.G vs Sentinels
#
#          Map       Team        Type  Initiated  Won
# 0      Haven      Gen.G  Pistol Won        NaN    2
# 5      Haven  Sentinels  Pistol Won        NaN    0
# 10    Ascent      Gen.G  Pistol Won        NaN    1
# 15    Ascent  Sentinels  Pistol Won        NaN    1
# 20  All Maps      Gen.G  Pistol Won        NaN    3

# %% [markdown]
# It is possible for 'Initiated' to have null values since players do not have enough money to have a specific economy (eco, full buy, etc.) on pistol round which happens on the first round of each half. Therefore, no missing values are dropped or imputed.

# %%
vct24_eco_stats_clean = vct24_eco_stats.copy()

# save the data in data/02-processed
vct24_eco_stats_clean.to_csv(
    "data/02-processed/vct_both_2024_2025/vct_2024/eco_stats.csv",
    index=False
)

# %%
vct24_overview.isna().sum()
# Out:
# Tournament                            0
# Stage                                 0
# Match Type                            0
# Match Name                            0
# Map                                   0
# Player                                0
# Team                                  0
# Agents                                0
# Rating                            12090
# Average Combat Score               8069
# Kills                              8060
# Deaths                             8060
# Assists                            8060
# Kills - Deaths (KD)                8062
# Kill, Assist, Trade, Survive %    12100
# Average Damage Per Round          10051
# Headshot %                        10068
# First Kills                       10040
# First Deaths                      10040
# Kills - Deaths (FKD)              10040
# Side                                  0
# dtype: int64

# %%
# look into missing entries
vct24_overview[
    vct24_overview.isna().any(axis=1)
].head(10)
# Out:
#                                  Tournament           Stage  \
# 2327                Valorant Champions 2024        Playoffs
# 2422                Valorant Champions 2024        Playoffs
# 5918  Champions Tour 2024: Americas Stage 2  Regular Season
# 5921  Champions Tour 2024: Americas Stage 2  Regular Season
# 5924  Champions Tour 2024: Americas Stage 2  Regular Season
# 5935  Champions Tour 2024: Americas Stage 2  Regular Season
# 6353  Champions Tour 2024: Americas Stage 2        Playoffs
# 7050     Champions Tour 2024: China Stage 2  Regular Season
# 7051     Champions Tour 2024: China Stage 2  Regular Season
# 7052     Champions Tour 2024: China Stage 2  Regular Season
#
#                Match Type                         Match Name     Map  \
# 2327  Upper Quarterfinals            Team Heretics vs FNATIC   Lotus
# 2422        Lower Round 1               DRX vs Trace Esports   Lotus
# 5918               Week 4                LOUD vs 100 Thieves  Ascent
# 5921               Week 4                LOUD vs 100 Thieves  Ascent
# 5924               Week 4                LOUD vs 100 Thieves  Ascent
# 5935               Week 4                LOUD vs 100 Thieves  Ascent
# 6353     Upper Semifinals            LEVIATÁN vs KRÜ Esports  Icebox
# 7050               Week 1  Titan Esports Club vs JDG Esports  Icebox
# 7051               Week 1  Titan Esports Club vs JDG Esports  Icebox
# 7052               Week 1  Titan Esports Club vs JDG Esports  Icebox
#
#         Player                Team  Agents  Rating  Average Combat Score  ...  \
# 2327     Derke              FNATIC    raze    0.01                  23.0  ...
# 2422     Biank       Trace Esports    fade    0.01                   6.0  ...
# 5918  cauanzin                LOUD    sova    0.03                  76.0  ...
# 5921      Less                LOUD  cypher    0.16                  28.0  ...
# 5924      tuyz                LOUD    jett    0.01                  20.0  ...
# 5935      bang         100 Thieves    omen    0.48                  13.0  ...
# 6353       mta         KRÜ Esports    sova    0.02                  27.0  ...
# 7050       Abo  Titan Esports Club    jett     NaN                 295.0  ...
# 7051       Abo  Titan Esports Club    jett     NaN                   NaN  ...
# 7052       Abo  Titan Esports Club    jett     NaN                   NaN  ...
#
#       Deaths  Assists  Kills - Deaths (KD)  Kill, Assist, Trade, Survive %  \
# 2327     4.0      0.0                 -4.0                             NaN
# 2422     4.0      1.0                 -4.0                             25%
# 5918     2.0      0.0                 -2.0                             NaN
# 5921     2.0      0.0                 -2.0                             NaN
# 5924     2.0      0.0                 -2.0                             NaN
# 5935     1.0      1.0                 -1.0                            100%
# 6353     3.0      0.0                 -3.0                             NaN
# 7050    21.0      4.0                  7.0                             NaN
# 7051     NaN      NaN                  NaN                             NaN
# 7052     NaN      NaN                  NaN                             NaN
#
#      Average Damage Per Round  Headshot % First Kills  First Deaths  \
# 2327                     23.0          0%         0.0           1.0
# 2422                      0.0         NaN         0.0           1.0
# 5918                     76.0         25%         0.0           0.0
# 5921                     28.0          0%         0.0           0.0
# 5924                     20.0          0%         0.0           0.0
# 5935                      0.0         NaN         0.0           1.0
# 6353                     27.0          0%         0.0           1.0
# 7050                    192.0         22%         7.0           5.0
# 7051                      NaN         NaN         NaN           NaN
# 7052                      NaN         NaN         NaN           NaN
#
#       Kills - Deaths (FKD)    Side
# 2327                  -1.0  defend
# 2422                  -1.0  attack
# 5918                   0.0  defend
# 5921                   0.0  defend
# 5924                   0.0  defend
# 5935                  -1.0  attack
# 6353                  -1.0  defend
# 7050                   2.0    both
# 7051                   NaN  attack
# 7052                   NaN  defend
#
# [10 rows x 21 columns]

# %%
# look for potential outliers
vct24_overview[
    (vct24_overview["Rating"] > 2) |
    (vct24_overview["Average Damage Per Round"] > 300)
][["Player", "Rating", "Average Damage Per Round"]].head(10)
# Out:
#       Player  Rating  Average Damage Per Round
# 106    RieNs    2.45                     286.0
# 225   Melser    2.45                     247.0
# 226   Melser    3.19                     274.0
# 227   Melser    2.26                     240.0
# 301     BuZz    2.09                     310.0
# 391     hiro    2.33                     280.0
# 571    trexx    2.32                     247.0
# 1010    MaKo    2.01                     219.0
# 1112   kiNgg    2.04                     194.0
# 1129   FengF    2.22                     284.0

# %%
## fill count-based stats where NaN indicates zero occurrences
vct24_overview[
    ["First Kills", "First Deaths", "Kills - Deaths (FKD)"]
] = vct24_overview[
    ["First Kills", "First Deaths", "Kills - Deaths (FKD)"]
].fillna(0)


vct24_overview_clean = vct24_overview.copy()

## save wrangled data
vct24_overview_clean.to_csv(
    "data/02-processed/vct_both_2024_2025/vct_2024/overview.csv",
    index=False
)

# %%
vct24_scores.isna().sum()
# Out:
# Tournament      0
# Stage           0
# Match Type      0
# Match Name      0
# Team A          0
# Team B          0
# Team A Score    0
# Team B Score    0
# Match Result    0
# dtype: int64

# %%
vct24_team_mapping.isna().sum()
# Out:
# Abbreviated    0
# Full Name      0
# dtype: int64

# %%
vct24_winloss_count.isna().sum()
# Out:
# Tournament                       0
# Stage                            0
# Match Type                       0
# Match Name                       0
# Map                              0
# Team                             0
# Elimination                      0
# Detonated                        0
# Defused                          0
# Time Expiry (No Plant)           0
# Eliminated                       0
# Defused Failed                   0
# Detonation Denied                0
# Time Expiry (Failed to Plant)    0
# dtype: int64

# %%
vct24_winloss_round.isna().sum()
# Out:
# Tournament      0
# Stage           0
# Match Type      0
# Match Name      0
# Map             0
# Round Number    0
# Team            0
# Method          0
# Outcome         0
# dtype: int64

# %%
vct24_players_stats.isna().sum()
# Out:
# Tournament                           0
# Stage                                0
# Match Type                           0
# Player                               0
# Teams                                0
# Agents                               0
# Rounds Played                        0
# Rating                            3978
# Average Combat Score                 0
# Kills:Deaths                         0
# Kill, Assist, Trade, Survive %    3978
# Average Damage Per Round          1983
# Kills Per Round                      0
# Assists Per Round                    0
# First Kills Per Round             1983
# First Deaths Per Round            1983
# Headshot %                        3979
# Clutch Success %                  4653
# Clutches (won/played)             4653
# Maximum Kills in a Single Map        0
# Kills                                0
# Deaths                               0
# Assists                              0
# First Kills                          0
# First Deaths                         0
# dtype: int64

# %%
# look into missing entries
vct24_players_stats[
    vct24_players_stats[[
        "Rating",
        "Kill, Assist, Trade, Survive %",
        "Average Damage Per Round",
        "Headshot %",
        "Clutch Success %"
    ]].isna().any(axis=1)
][["Player", "Rounds Played",
   "Rating", "Average Damage Per Round",
   "Headshot %", "Clutch Success %"]].head(10)
# Out:
#          Player  Rounds Played  Rating  Average Damage Per Round Headshot %  \
# 1           Boo             16    1.10                     122.0        21%
# 3    benjyfishy             26    0.85                     128.0        34%
# 27         hiro             16    0.73                      92.0        19%
# 47         BuZz             28    0.73                     130.0        27%
# 60        Biank             23    0.79                     127.0        40%
# 74       ZmjjKK             23    1.48                     214.0        30%
# 77          tex             18    0.12                      81.0        25%
# 80       Mazino             48    0.92                     132.0        27%
# 134     MiniBoo             28    1.06                     168.0        37%
# 142     CHICHOO             17    1.26                     132.0        22%
#
#     Clutch Success %
# 1                NaN
# 3                NaN
# 27               NaN
# 47               NaN
# 60               NaN
# 74               NaN
# 77               NaN
# 80               NaN
# 134              NaN
# 142              NaN

# %%
## missing values are expected due to limited rounds or in-game situations
vct24_players_stats_clean = vct24_players_stats.copy()

## save wrangled data
vct24_players_stats_clean.to_csv(
    "data/02-processed/vct_both_2024_2025/vct_2024/players_stats.csv",
    index=False
)

# %% [markdown]
# #### VCT 2025 Folder Exploration

# %%
# vct 2025 folder

# agents folder
vct25_agents_pick = pd.read_csv('data/00-raw/vct_both_2024_2025/vct_2025/agents/agents_pick_rates.csv')
vct25_maps_stats = pd.read_csv('data/00-raw/vct_both_2024_2025/vct_2025/agents/maps_stats.csv')
vct25_teams_pick = pd.read_csv('data/00-raw/vct_both_2024_2025/vct_2025/agents/teams_picked_agents.csv')

# ids folder
vct25_players_ids = pd.read_csv('data/00-raw/vct_both_2024_2025/vct_2025/ids/players_ids.csv')
vct25_teams_ids = pd.read_csv('data/00-raw/vct_both_2024_2025/vct_2025/ids/teams_ids.csv')
vct25_tournaments_types = pd.read_csv('data/00-raw/vct_both_2024_2025/vct_2025/ids/tournaments_stages_match_types_ids.csv')
vct25_tournaments_games = pd.read_csv('data/00-raw/vct_both_2024_2025/vct_2025/ids/tournaments_stages_matches_games_ids.csv')

# matches folder
vct25_eco_rounds = pd.read_csv('data/00-raw/vct_both_2024_2025/vct_2025/matches/eco_rounds.csv')
vct25_eco_stats = pd.read_csv('data/00-raw/vct_both_2024_2025/vct_2025/matches/eco_stats.csv')

vct25_overview = pd.read_csv('data/00-raw/vct_both_2024_2025/vct_2025/matches/overview.csv')
vct25_scores = pd.read_csv('data/00-raw/vct_both_2024_2025/vct_2025/matches/scores.csv')

vct25_team_mapping = pd.read_csv('data/00-raw/vct_both_2024_2025/vct_2025/matches/team_mapping.csv')

vct25_winloss_count = pd.read_csv('data/00-raw/vct_both_2024_2025/vct_2025/matches/win_loss_methods_count.csv')
vct25_winloss_round = pd.read_csv('data/00-raw/vct_both_2024_2025/vct_2025/matches/win_loss_methods_round_number.csv')

# players_stats folder
vct25_players_stats = pd.read_csv('data/00-raw/vct_both_2024_2025/vct_2025/players_stats/players_stats.csv')

# %%
print(vct25_agents_pick.shape)
vct25_agents_pick.head()
# Out:
# (30294, 6)
#                 Tournament     Stage           Match Type       Map  Agent  \
# 0  Valorant Champions 2025  Playoffs  Upper Quarterfinals  All Maps   omen
# 1  Valorant Champions 2025  Playoffs  Upper Quarterfinals  All Maps   yoru
# 2  Valorant Champions 2025  Playoffs  Upper Quarterfinals  All Maps  viper
# 3  Valorant Champions 2025  Playoffs  Upper Quarterfinals  All Maps   sova
# 4  Valorant Champions 2025  Playoffs  Upper Quarterfinals  All Maps   vyse
#
#   Pick Rate
# 0       95%
# 1       60%
# 2       55%
# 3       55%
# 4       50%

# %%
print(vct25_maps_stats.shape)
vct25_maps_stats.head()
# Out:
# (1122, 7)
#                 Tournament     Stage           Match Type       Map  \
# 0  Valorant Champions 2025  Playoffs  Upper Quarterfinals  All Maps
# 1  Valorant Champions 2025  Playoffs  Upper Quarterfinals     Lotus
# 2  Valorant Champions 2025  Playoffs  Upper Quarterfinals    Ascent
# 3  Valorant Champions 2025  Playoffs  Upper Quarterfinals   Corrode
# 4  Valorant Champions 2025  Playoffs  Upper Quarterfinals     Haven
#
#    Total Maps Played Attacker Side Win Percentage Defender Side Win Percentage
# 0                 10                          62%                          38%
# 1                  3                          56%                          44%
# 2                  2                          67%                          33%
# 3                  2                          58%                          42%
# 4                  2                          84%                          16%

# %%
print(vct25_teams_pick.shape)
vct25_teams_pick.head()
# Out:
# (18396, 9)
#                 Tournament     Stage           Match Type    Map    Team  \
# 0  Valorant Champions 2025  Playoffs  Upper Quarterfinals  Haven  FNATIC
# 1  Valorant Champions 2025  Playoffs  Upper Quarterfinals  Haven  FNATIC
# 2  Valorant Champions 2025  Playoffs  Upper Quarterfinals  Haven  FNATIC
# 3  Valorant Champions 2025  Playoffs  Upper Quarterfinals  Haven  FNATIC
# 4  Valorant Champions 2025  Playoffs  Upper Quarterfinals  Haven  FNATIC
#
#      Agent  Total Wins By Map  Total Loss By Map  Total Maps Played
# 0     omen                  1                  0                  1
# 1     yoru                  1                  0                  1
# 2    viper                  1                  0                  1
# 3     sova                  1                  0                  1
# 4  killjoy                  1                  0                  1

# %%
print(vct25_players_ids.shape)
vct25_players_ids.head()
# Out:
# (349, 2)
#       Player  Player ID
# 0  something    17086.0
# 1     Jinggg     7378.0
# 2   f0rsakeN     9801.0
# 3      d4v41     9803.0
# 4     PatMen    13744.0

# %%
print(vct25_teams_ids.shape)
vct25_teams_ids.head()
# Out:
# (58, 2)
#             Team  Team ID
# 0      Paper Rex      624
# 1  Xi Lai Gaming    13581
# 2         GIANTX    14419
# 3      Sentinels        2
# 4            NRG     1034

# %%
print(vct25_tournaments_types.shape)
vct25_tournaments_types.head()
# Out:
# (202, 6)
#                 Tournament  Tournament ID     Stage  Stage ID  \
# 0  Valorant Champions 2025           2283  Playoffs    5080.0
# 1  Valorant Champions 2025           2283  Playoffs    5080.0
# 2  Valorant Champions 2025           2283  Playoffs    5080.0
# 3  Valorant Champions 2025           2283  Playoffs    5080.0
# 4  Valorant Champions 2025           2283  Playoffs    5080.0
#
#             Match Type  Match Type ID
# 0  Upper Quarterfinals        33667.0
# 1     Upper Semifinals        33668.0
# 2          Upper Final        33669.0
# 3          Grand Final        33670.0
# 4        Lower Round 1        33671.0

# %%
print(vct25_tournaments_games.shape)
vct25_tournaments_games.head()
# Out:
# (1277, 9)
#                 Tournament  Tournament ID        Stage  Stage ID   Match Type  \
# 0  Valorant Champions 2025           2283  Group Stage      5079  Opening (A)
# 1  Valorant Champions 2025           2283  Group Stage      5079  Opening (A)
# 2  Valorant Champions 2025           2283  Group Stage      5079  Opening (A)
# 3  Valorant Champions 2025           2283  Group Stage      5079  Opening (A)
# 4  Valorant Champions 2025           2283  Group Stage      5079  Opening (A)
#
#                    Match Name  Match ID      Map  Game ID
# 0  Paper Rex vs Xi Lai Gaming    542195     Bind   233397
# 1  Paper Rex vs Xi Lai Gaming    542195   Sunset   233398
# 2         GIANTX vs Sentinels    542196  Corrode   233400
# 3         GIANTX vs Sentinels    542196   Sunset   233401
# 4         GIANTX vs Sentinels    542196    Haven   233402

# %%
print(vct25_eco_rounds.shape)
vct25_eco_rounds.head()
# Out:
# (25182, 11)
#                       Tournament        Stage Match Type  \
# 0  Valorant Masters Toronto 2025  Swiss Stage    Round 1
# 1  Valorant Masters Toronto 2025  Swiss Stage    Round 1
# 2  Valorant Masters Toronto 2025  Swiss Stage    Round 1
# 3  Valorant Masters Toronto 2025  Swiss Stage    Round 1
# 4  Valorant Masters Toronto 2025  Swiss Stage    Round 1
#
#                    Match Name    Map  Round Number           Team  \
# 0  Team Heretics vs Paper Rex  Pearl             1  Team Heretics
# 1  Team Heretics vs Paper Rex  Pearl             1      Paper Rex
# 2  Team Heretics vs Paper Rex  Pearl             2  Team Heretics
# 3  Team Heretics vs Paper Rex  Pearl             2      Paper Rex
# 4  Team Heretics vs Paper Rex  Pearl             3  Team Heretics
#
#   Loadout Value Remaining Credits              Type Outcome
# 0           NaN              0.2k         Eco: 0-5k    Loss
# 1           NaN              0.5k         Eco: 0-5k     Win
# 2           NaN             10.2k         Eco: 0-5k    Loss
# 3           NaN              2.3k  Semi-buy: 10-20k     Win
# 4           NaN              0.2k    Full buy: 20k+     Win

# %%
print(vct25_eco_stats.shape)
vct25_eco_stats.head()
# Out:
# (13940, 9)
#                 Tournament        Stage   Match Type  \
# 0  Valorant Champions 2025  Group Stage  Opening (A)
# 1  Valorant Champions 2025  Group Stage  Opening (A)
# 2  Valorant Champions 2025  Group Stage  Opening (A)
# 3  Valorant Champions 2025  Group Stage  Opening (A)
# 4  Valorant Champions 2025  Group Stage  Opening (A)
#
#                    Match Name   Map       Team        Type  Initiated  Won
# 0  Paper Rex vs Xi Lai Gaming  Bind  Paper Rex  Pistol Won        NaN    1
# 1  Paper Rex vs Xi Lai Gaming  Bind  Paper Rex   Eco (won)        4.0    2
# 2  Paper Rex vs Xi Lai Gaming  Bind  Paper Rex     $ (won)        0.0    0
# 3  Paper Rex vs Xi Lai Gaming  Bind  Paper Rex    $$ (won)        3.0    2
# 4  Paper Rex vs Xi Lai Gaming  Bind  Paper Rex   $$$ (won)       15.0    9

# %%
print(vct25_overview.shape)
vct25_overview.head()
# Out:
# (53226, 21)
#                 Tournament        Stage   Match Type  \
# 0  Valorant Champions 2025  Group Stage  Opening (A)
# 1  Valorant Champions 2025  Group Stage  Opening (A)
# 2  Valorant Champions 2025  Group Stage  Opening (A)
# 3  Valorant Champions 2025  Group Stage  Opening (A)
# 4  Valorant Champions 2025  Group Stage  Opening (A)
#
#                    Match Name   Map     Player       Team Agents  Rating  \
# 0  Paper Rex vs Xi Lai Gaming  Bind  something  Paper Rex   yoru    1.63
# 1  Paper Rex vs Xi Lai Gaming  Bind  something  Paper Rex   yoru    1.33
# 2  Paper Rex vs Xi Lai Gaming  Bind  something  Paper Rex   yoru    1.88
# 3  Paper Rex vs Xi Lai Gaming  Bind     Jinggg  Paper Rex   raze    1.52
# 4  Paper Rex vs Xi Lai Gaming  Bind     Jinggg  Paper Rex   raze    1.11
#
#    Average Combat Score  ...  Deaths  Assists  Kills - Deaths (KD)  \
# 0                 258.0  ...    12.0     12.0                  9.0
# 1                 199.0  ...     5.0      6.0                  2.0
# 2                 308.0  ...     7.0      6.0                  7.0
# 3                 315.0  ...    14.0      7.0                 10.0
# 4                 239.0  ...     7.0      2.0                  1.0
#
#    Kill, Assist, Trade, Survive % Average Damage Per Round  Headshot %  \
# 0                             91%                    167.0         15%
# 1                            100%                    137.0         16%
# 2                             83%                    192.0         13%
# 3                             82%                    207.0         18%
# 4                             80%                    148.0         13%
#
#   First Kills  First Deaths  Kills - Deaths (FKD)    Side
# 0         4.0           0.0                   4.0    both
# 1         1.0           0.0                   1.0  attack
# 2         3.0           0.0                   3.0  defend
# 3         5.0           2.0                   3.0    both
# 4         3.0           2.0                   1.0  attack
#
# [5 rows x 21 columns]

# %%
print(vct25_scores.shape)
vct25_scores.head()
# Out:
# (503, 9)
#                 Tournament        Stage   Match Type  \
# 0  Valorant Champions 2025  Group Stage  Opening (A)
# 1  Valorant Champions 2025  Group Stage  Opening (A)
# 2  Valorant Champions 2025  Group Stage  Opening (C)
# 3  Valorant Champions 2025  Group Stage  Opening (C)
# 4  Valorant Champions 2025  Group Stage  Opening (D)
#
#                    Match Name                Team A         Team B  \
# 0  Paper Rex vs Xi Lai Gaming             Paper Rex  Xi Lai Gaming
# 1         GIANTX vs Sentinels                GIANTX      Sentinels
# 2        NRG vs EDward Gaming           Mega Minors  EDward Gaming
# 3          Team Liquid vs DRX           Team Liquid            DRX
# 4  Dragon Ranger Gaming vs T1  Dragon Ranger Gaming             T1
#
#    Team A Score  Team B Score   Match Result
# 0             2             0  Paper Rex won
# 1             2             1     GIANTX won
# 2             2             0        NRG won
# 3             0             2        DRX won
# 4             0             2         T1 won

# %%
print(vct25_team_mapping.shape)
vct25_team_mapping.head()
# Out:
# (58, 2)
#   Abbreviated      Full Name
# 0         PRX      Paper Rex
# 1         XLG  Xi Lai Gaming
# 2          GX         GIANTX
# 3         SEN      Sentinels
# 4         NRG            NRG

# %%
print(vct25_winloss_count.shape)
vct25_winloss_count.head()
# Out:
# (2554, 14)
#                 Tournament        Stage   Match Type  \
# 0  Valorant Champions 2025  Group Stage  Opening (A)
# 1  Valorant Champions 2025  Group Stage  Opening (A)
# 2  Valorant Champions 2025  Group Stage  Opening (A)
# 3  Valorant Champions 2025  Group Stage  Opening (A)
# 4  Valorant Champions 2025  Group Stage  Opening (A)
#
#                    Match Name      Map           Team  Elimination  Detonated  \
# 0  Paper Rex vs Xi Lai Gaming     Bind      Paper Rex            8          1
# 1  Paper Rex vs Xi Lai Gaming     Bind  Xi Lai Gaming            3          3
# 2  Paper Rex vs Xi Lai Gaming   Sunset      Paper Rex            9          0
# 3  Paper Rex vs Xi Lai Gaming   Sunset  Xi Lai Gaming            3          2
# 4         GIANTX vs Sentinels  Corrode         GIANTX            4          0
#
#    Defused  Time Expiry (No Plant)  Eliminated  Defused Failed  \
# 0        3                       1           3               3
# 1        2                       1           8               1
# 2        4                       0           3               2
# 3        0                       0           9               0
# 4        1                       1           8               3
#
#    Detonation Denied  Time Expiry (Failed to Plant)
# 0                  2                              1
# 1                  3                              1
# 2                  0                              0
# 3                  4                              0
# 4                  2                              0

# %%
print(vct25_winloss_round.shape)
vct25_winloss_round.head()
# Out:
# (53950, 9)
#                 Tournament        Stage   Match Type  \
# 0  Valorant Champions 2025  Group Stage  Opening (A)
# 1  Valorant Champions 2025  Group Stage  Opening (A)
# 2  Valorant Champions 2025  Group Stage  Opening (A)
# 3  Valorant Champions 2025  Group Stage  Opening (A)
# 4  Valorant Champions 2025  Group Stage  Opening (A)
#
#                    Match Name   Map  Round Number           Team  \
# 0  Paper Rex vs Xi Lai Gaming  Bind             1  Xi Lai Gaming
# 1  Paper Rex vs Xi Lai Gaming  Bind             1      Paper Rex
# 2  Paper Rex vs Xi Lai Gaming  Bind             2  Xi Lai Gaming
# 3  Paper Rex vs Xi Lai Gaming  Bind             2      Paper Rex
# 4  Paper Rex vs Xi Lai Gaming  Bind             3      Paper Rex
#
#            Method Outcome
# 0     Elimination     Win
# 1      Eliminated    Loss
# 2       Detonated     Win
# 3  Failed Defused    Loss
# 4         Defused     Win

# %%
print(vct25_players_stats.shape)
vct25_players_stats.head()
# Out:
# (17996, 25)
#                 Tournament     Stage           Match Type Player  \
# 0  Valorant Champions 2025  Playoffs  Upper Quarterfinals    Boo
# 1  Valorant Champions 2025  Playoffs  Upper Quarterfinals    Boo
# 2  Valorant Champions 2025  Playoffs  Upper Quarterfinals    Boo
# 3  Valorant Champions 2025  Playoffs  Upper Quarterfinals  RieNs
# 4  Valorant Champions 2025  Playoffs  Upper Quarterfinals  RieNs
#
#            Teams       Agents  Rounds Played  Rating  Average Combat Score  \
# 0  Team Heretics        astra             26    0.68                 129.0
# 1  Team Heretics         omen             19    0.46                  98.0
# 2  Team Heretics  astra, omen             45    0.59                 114.0
# 3  Team Heretics         fade             26    1.21                 219.0
# 4  Team Heretics         sova             19    1.02                 220.0
#
#    Kills:Deaths  ... First Deaths Per Round  Headshot %  Clutch Success %  \
# 0          0.61  ...                   0.12         44%               NaN
# 1          0.40  ...                   0.26         37%               33%
# 2          0.52  ...                   0.18         41%               14%
# 3          1.13  ...                   0.04         23%               33%
# 4          0.75  ...                   0.05         28%               NaN
#
#    Clutches (won/played)  Maximum Kills in a Single Map  Kills Deaths Assists  \
# 0                    0/4                             11     11     18       4
# 1                    1/3                              6      6     15       5
# 2                    1/7                             11     17     33       9
# 3                    1/3                             18     18     16      10
# 4                    0/4                             12     12     16       5
#
#   First Kills  First Deaths
# 0           3             3
# 1           1             5
# 2           4             8
# 3           2             1
# 4           1             1
#
# [5 rows x 25 columns]

# %%
vct25_agents_pick.isna().sum()
# Out:
# Tournament    0
# Stage         0
# Match Type    0
# Map           0
# Agent         0
# Pick Rate     0
# dtype: int64

# %%
vct25_maps_stats.isna().sum()
# Out:
# Tournament                      0
# Stage                           0
# Match Type                      0
# Map                             0
# Total Maps Played               0
# Attacker Side Win Percentage    0
# Defender Side Win Percentage    0
# dtype: int64

# %%
vct25_teams_pick.isna().sum()
# Out:
# Tournament           0
# Stage                0
# Match Type           0
# Map                  0
# Team                 0
# Agent                0
# Total Wins By Map    0
# Total Loss By Map    0
# Total Maps Played    0
# dtype: int64

# %%
vct25_players_ids.isna().sum()
# Out:
# Player       0
# Player ID    2
# dtype: int64

# %%
# look into missing entries
vct25_players_ids[vct25_players_ids['Player ID'].isna()]
# Out:
#         Player  Player ID
# 331     karsaj        NaN
# 334  heart bus        NaN

# %% [markdown]
# Having the player ID be a null value is not a big problem since we will not be looking into individual players.

# %%
vct25_teams_ids.isna().sum()
# Out:
# Team       0
# Team ID    0
# dtype: int64

# %%
vct25_tournaments_types.isna().sum()
# Out:
# Tournament        0
# Tournament ID     0
# Stage             0
# Stage ID         15
# Match Type        0
# Match Type ID    15
# dtype: int64

# %%
# look into missing entries
vct25_tournaments_types[
    vct25_tournaments_types["Stage ID"].isna() |
    vct25_tournaments_types["Match Type ID"].isna()
]
# Out:
#                         Tournament  Tournament ID       Stage  Stage ID  \
# 24         Valorant Champions 2025           2283  All Stages       NaN
# 37       VCT 2025: Pacific Stage 2           2500  All Stages       NaN
# 50         VCT 2025: China Stage 2           2499  All Stages       NaN
# 64          VCT 2025: EMEA Stage 2           2498  All Stages       NaN
# 78      VCT 2025: Americas Stage 2           2501  All Stages       NaN
# 91   Valorant Masters Toronto 2025           2282  All Stages       NaN
# 105         VCT 2025: EMEA Stage 1           2380  All Stages       NaN
# 119      VCT 2025: Pacific Stage 1           2379  All Stages       NaN
# 133        VCT 2025: China Stage 1           2359  All Stages       NaN
# 147     VCT 2025: Americas Stage 1           2347  All Stages       NaN
# 157  Valorant Masters Bangkok 2025           2281  All Stages       NaN
# 168         VCT 2025: EMEA Kickoff           2276  All Stages       NaN
# 179      VCT 2025: Pacific Kickoff           2277  All Stages       NaN
# 190     VCT 2025: Americas Kickoff           2274  All Stages       NaN
# 201        VCT 2025: China Kickoff           2275  All Stages       NaN
#
#           Match Type  Match Type ID
# 24   All Match Types            NaN
# 37   All Match Types            NaN
# 50   All Match Types            NaN
# 64   All Match Types            NaN
# 78   All Match Types            NaN
# 91   All Match Types            NaN
# 105  All Match Types            NaN
# 119  All Match Types            NaN
# 133  All Match Types            NaN
# 147  All Match Types            NaN
# 157  All Match Types            NaN
# 168  All Match Types            NaN
# 179  All Match Types            NaN
# 190  All Match Types            NaN
# 201  All Match Types            NaN

# %%
## missing values are expected, so no rows are dropped and no imputation is performed
vct25_tournaments_types_cleaned = vct25_tournaments_types.copy()

## verify cleaned dataset
print(vct25_tournaments_types_cleaned.shape)

# save the data in data/02-processed
vct25_tournaments_types_cleaned.to_csv(
    "data/02-processed/vct_both_2024_2025/vct_2025/tournaments_stages_match_types_ids.csv",
    index=False
)
# Out:
# (202, 6)

# %%
vct25_tournaments_games.isna().sum()
# Out:
# Tournament       0
# Tournament ID    0
# Stage            0
# Stage ID         0
# Match Type       0
# Match Name       0
# Match ID         0
# Map              0
# Game ID          0
# dtype: int64

# %%
vct25_eco_rounds.isna().sum()
# Out:
# Tournament              0
# Stage                   0
# Match Type              0
# Match Name              0
# Map                     0
# Round Number            0
# Team                    0
# Loadout Value        2550
# Remaining Credits       0
# Type                    0
# Outcome                 0
# dtype: int64

# %%
vct25_eco_rounds[vct25_eco_rounds['Loadout Value'].isna()].head()
# Out:
#                       Tournament        Stage Match Type  \
# 0  Valorant Masters Toronto 2025  Swiss Stage    Round 1
# 1  Valorant Masters Toronto 2025  Swiss Stage    Round 1
# 2  Valorant Masters Toronto 2025  Swiss Stage    Round 1
# 3  Valorant Masters Toronto 2025  Swiss Stage    Round 1
# 4  Valorant Masters Toronto 2025  Swiss Stage    Round 1
#
#                    Match Name    Map  Round Number           Team  \
# 0  Team Heretics vs Paper Rex  Pearl             1  Team Heretics
# 1  Team Heretics vs Paper Rex  Pearl             1      Paper Rex
# 2  Team Heretics vs Paper Rex  Pearl             2  Team Heretics
# 3  Team Heretics vs Paper Rex  Pearl             2      Paper Rex
# 4  Team Heretics vs Paper Rex  Pearl             3  Team Heretics
#
#   Loadout Value Remaining Credits              Type Outcome
# 0           NaN              0.2k         Eco: 0-5k    Loss
# 1           NaN              0.5k         Eco: 0-5k     Win
# 2           NaN             10.2k         Eco: 0-5k    Loss
# 3           NaN              2.3k  Semi-buy: 10-20k     Win
# 4           NaN              0.2k    Full buy: 20k+     Win

# %% [markdown]
# While there is a large amount of nulls in the ``Loadout Value`` column, we will not be removing these rows since our focus is on headshot percentage and agent pick rate.

# %%
vct24_eco_rounds_clean = vct24_eco_rounds.copy()

# save the data in data/02-processed
vct24_eco_rounds_clean.to_csv(
    "data/02-processed/vct_both_2024_2025/vct_2025/eco_rounds.csv",
    index=False
)

# %%
vct25_eco_stats.isna().sum()
# Out:
# Tournament       0
# Stage            0
# Match Type       0
# Match Name       0
# Map              0
# Team             0
# Type             0
# Initiated     2788
# Won              0
# dtype: int64

# %%
# look into missing entries
vct25_eco_stats[vct25_eco_stats['Initiated'].isna()].head()
# Out:
#                  Tournament        Stage   Match Type  \
# 0   Valorant Champions 2025  Group Stage  Opening (A)
# 5   Valorant Champions 2025  Group Stage  Opening (A)
# 10  Valorant Champions 2025  Group Stage  Opening (A)
# 15  Valorant Champions 2025  Group Stage  Opening (A)
# 20  Valorant Champions 2025  Group Stage  Opening (A)
#
#                     Match Name       Map           Team        Type  \
# 0   Paper Rex vs Xi Lai Gaming      Bind      Paper Rex  Pistol Won
# 5   Paper Rex vs Xi Lai Gaming      Bind  Xi Lai Gaming  Pistol Won
# 10  Paper Rex vs Xi Lai Gaming    Sunset      Paper Rex  Pistol Won
# 15  Paper Rex vs Xi Lai Gaming    Sunset  Xi Lai Gaming  Pistol Won
# 20  Paper Rex vs Xi Lai Gaming  All Maps      Paper Rex  Pistol Won
#
#     Initiated  Won
# 0         NaN    1
# 5         NaN    1
# 10        NaN    2
# 15        NaN    0
# 20        NaN    3

# %% [markdown]
# Similar to the 2024 data, it is possible for 'Initiated' to have null values since players do not have enough money to have a specific economy (eco, full buy, etc.) on pistol round which happens on the first round of each half. Therefore, no missing values are dropped or imputed.

# %%
vct25_eco_stats_clean = vct25_eco_stats.copy()

# save the data in data/02-processed
vct25_eco_stats_clean.to_csv(
    "data/02-processed/vct_both_2024_2025/vct_2025/eco_stats.csv",
    index=False
)

# %%
vct25_overview.isna().sum()
# Out:
# Tournament                           0
# Stage                                0
# Match Type                           0
# Match Name                           0
# Map                                  0
# Player                               0
# Team                                 0
# Agents                               0
# Rating                            4080
# Average Combat Score              2745
# Kills                             2550
# Deaths                            2550
# Assists                           2550
# Kills - Deaths (KD)               2556
# Kill, Assist, Trade, Survive %    3882
# Average Damage Per Round          4056
# Headshot %                        3849
# First Kills                       3960
# First Deaths                      3957
# Kills - Deaths (FKD)              3957
# Side                                 0
# dtype: int64

# %%
# look into missing entries
vct25_overview[
    vct25_overview.isna().any(axis=1)
].head(10)
# Out:
#                       Tournament        Stage           Match Type  \
# 97       Valorant Champions 2025  Group Stage          Opening (A)
# 574      Valorant Champions 2025  Group Stage          Opening (B)
# 580      Valorant Champions 2025  Group Stage          Opening (B)
# 1205     Valorant Champions 2025  Group Stage      Elimination (C)
# 1537     Valorant Champions 2025  Group Stage      Elimination (B)
# 2345     Valorant Champions 2025     Playoffs  Upper Quarterfinals
# 2354     Valorant Champions 2025     Playoffs  Upper Quarterfinals
# 2579     Valorant Champions 2025     Playoffs        Lower Round 1
# 2620     Valorant Champions 2025     Playoffs        Lower Round 1
# 4064  VCT 2025: Americas Stage 2  Group Stage               Week 1
#
#                              Match Name      Map    Player             Team  \
# 97                  GIANTX vs Sentinels  Corrode  westside           GIANTX
# 574             Bilibili Gaming vs MIBR    Haven      whzy  Bilibili Gaming
# 580             Bilibili Gaming vs MIBR    Haven    Levius  Bilibili Gaming
# 1205       Team Liquid vs EDward Gaming   Sunset   paTiTek      Team Liquid
# 1537  Bilibili Gaming vs Rex Regum Qeon    Abyss    Knight  Bilibili Gaming
# 2345                      NRG vs GIANTX    Haven      mada      Mega Minors
# 2354                      NRG vs GIANTX    Haven     skuba      Mega Minors
# 2579            Team Heretics vs GIANTX   Ascent  grubinho           GIANTX
# 2620            Team Heretics vs GIANTX    Lotus       Boo    Team Heretics
# 4064                MIBR vs KRÜ Esports   Ascent     Verno             MIBR
#
#        Agents  Rating  Average Combat Score  ...  Deaths  Assists  \
# 97       vyse    0.15                  25.0  ...     7.0      0.0
# 574      neon    0.02                   8.0  ...     3.0      1.0
# 580    cypher    0.02                  12.0  ...     3.0      0.0
# 1205     omen    0.34                  19.0  ...     3.0      3.0
# 1537     sova    0.13                  79.0  ...     5.0      0.0
# 2345     neon    0.29                   NaN  ...     1.0      0.0
# 2354  killjoy    0.92                  28.0  ...     0.0      0.0
# 2579     omen    0.03                  15.0  ...     5.0      3.0
# 2620     omen    0.05                  46.0  ...     4.0      0.0
# 4064     sova    0.01                   NaN  ...     2.0      0.0
#
#       Kills - Deaths (KD)  Kill, Assist, Trade, Survive %  \
# 97                   -7.0                             NaN
# 574                  -3.0                             33%
# 580                  -3.0                             NaN
# 1205                 -3.0                             75%
# 1537                 -5.0                             NaN
# 2345                 -1.0                             50%
# 2354                  NaN                            100%
# 2579                 -5.0                             60%
# 2620                 -4.0                             NaN
# 4064                 -2.0                             NaN
#
#      Average Damage Per Round  Headshot % First Kills  First Deaths  \
# 97                       25.0          0%         0.0           0.0
# 574                       0.0         NaN         0.0           1.0
# 580                      12.0          0%         0.0           2.0
# 1205                      NaN         NaN         0.0           0.0
# 1537                     79.0          0%         0.0           1.0
# 2345                      NaN         NaN         0.0           0.0
# 2354                     28.0         50%         0.0           0.0
# 2579                      NaN         NaN         0.0           2.0
# 2620                     46.0         33%         0.0           0.0
# 4064                      NaN         NaN         0.0           1.0
#
#       Kills - Deaths (FKD)    Side
# 97                     0.0  attack
# 574                   -1.0  attack
# 580                   -2.0  attack
# 1205                   0.0  defend
# 1537                  -1.0  attack
# 2345                   0.0  defend
# 2354                   0.0  defend
# 2579                  -2.0  defend
# 2620                   0.0  attack
# 4064                  -1.0  defend
#
# [10 rows x 21 columns]

# %%
# look for potential outliers
vct25_overview[
    (vct25_overview["Rating"] > 2) |
    (vct25_overview["Average Damage Per Round"] > 300)
][["Player", "Rating", "Average Damage Per Round"]].head(10)
# Out:
#          Player  Rating  Average Damage Per Round
# 64    something    2.11                     275.0
# 107     N4RRATE    2.39                     202.0
# 110      johnqt    2.03                     152.0
# 150       Cloud    2.05                     224.0
# 151       Cloud    2.60                     300.0
# 317        MaKo    2.20                     219.0
# 497  benjyfishy    2.02                     280.0
# 586       Verno    2.15                     203.0
# 599       xenom    2.20                     203.0
# 736     Boaster    2.73                     223.0

# %%
## fill count-based stats where NaN indicates zero occurrences
vct25_overview[
    ["First Kills", "First Deaths", "Kills - Deaths (FKD)"]
] = vct25_overview[
    ["First Kills", "First Deaths", "Kills - Deaths (FKD)"]
].fillna(0)

# %%
vct25_overview_clean = vct25_overview.copy()

## save wrangled data
vct25_overview_clean.to_csv(
    "data/02-processed/vct_both_2024_2025/vct_2025/overview.csv",
    index=False
)

# %%
vct25_scores.isna().sum()
# Out:
# Tournament      0
# Stage           0
# Match Type      0
# Match Name      0
# Team A          0
# Team B          0
# Team A Score    0
# Team B Score    0
# Match Result    0
# dtype: int64

# %%
vct25_team_mapping.isna().sum()
# Out:
# Abbreviated    0
# Full Name      0
# dtype: int64

# %%
vct25_winloss_count.isna().sum()
# Out:
# Tournament                       0
# Stage                            0
# Match Type                       0
# Match Name                       0
# Map                              0
# Team                             0
# Elimination                      0
# Detonated                        0
# Defused                          0
# Time Expiry (No Plant)           0
# Eliminated                       0
# Defused Failed                   0
# Detonation Denied                0
# Time Expiry (Failed to Plant)    0
# dtype: int64

# %%
vct25_winloss_round.isna().sum()
# Out:
# Tournament      0
# Stage           0
# Match Type      0
# Match Name      0
# Map             0
# Round Number    0
# Team            0
# Method          0
# Outcome         0
# dtype: int64

# %%
vct25_players_stats.isna().sum()
# Out:
# Tournament                            0
# Stage                                 0
# Match Type                            0
# Player                                0
# Teams                                 0
# Agents                                0
# Rounds Played                         0
# Rating                             1392
# Average Combat Score                 10
# Kills:Deaths                          0
# Kill, Assist, Trade, Survive %     1304
# Average Damage Per Round           1370
# Kills Per Round                       0
# Assists Per Round                     0
# First Kills Per Round              1351
# First Deaths Per Round             1350
# Headshot %                         1308
# Clutch Success %                  11337
# Clutches (won/played)              4733
# Maximum Kills in a Single Map         0
# Kills                                 0
# Deaths                                0
# Assists                               0
# First Kills                           0
# First Deaths                          0
# dtype: int64

# %%
# look into missing entries
vct25_players_stats[
    vct25_players_stats[[
        "Rating",
        "Average Combat Score",
        "Kill, Assist, Trade, Survive %",
        "Average Damage Per Round",
        "Headshot %",
        "Clutch Success %"
    ]].isna().any(axis=1)
][["Player", "Rounds Played",
   "Rating", "Average Damage Per Round",
   "Headshot %", "Clutch Success %"]].head(10)
# Out:
#        Player  Rounds Played  Rating  Average Damage Per Round Headshot %  \
# 0         Boo             26    0.68                      89.0        44%
# 4       RieNs             19    1.02                     142.0        28%
# 9   Flickless             14    0.47                      93.0        35%
# 10  Flickless             19    0.54                      95.0        19%
# 11  Flickless             33    0.51                      94.0        25%
# 14      Cloud             14    0.56                      88.0        24%
# 16        ara             14    0.25                      46.0        50%
# 17        ara             19    0.10                      38.0         9%
# 18        ara             33    0.17                      42.0        29%
# 19   grubinho             33    0.77                     118.0        36%
#
#    Clutch Success %
# 0               NaN
# 4               NaN
# 9               NaN
# 10              NaN
# 11              NaN
# 14              NaN
# 16              NaN
# 17              NaN
# 18              NaN
# 19              NaN

# %%
## missing values are expected due to limited rounds or in-game situations
vct25_players_stats_clean = vct25_players_stats.copy()

## save wrangled data
vct25_players_stats_clean.to_csv(
    "data/02-processed/vct_both_2024_2025/vct_2025/players_stats.csv",
    index=False
)

# %% [markdown]
# ## Results
#
# ### Exploratory Data Analysis
#
# Instructions: replace the words in this subsection with whatever words you need to setup and preview the EDA you're going to do.
#
# Please explicitly load the fully wrangled data you will use from `data/02-processed`.  This is a good idea rather than forcing people to re-run the data getting / wrangling cells above.  Sometimes it takes a long time to get / wrangle data compared to reloading the fixed up dataset.
#
# Carry out whatever EDA you need to for your project in the code cells below.  Because every project will be different we can't really give you much of a template at this point. But please make sure you describe the what and why in text here as well as providing interpretation of results and context.
#
# Please note that you should consider the use of python modules in your work.  Any code which gets called repeatedly should be modularized. So if you run the same pre-processing, analysis or visualiazation on different subsets of the data, then you should turn that into a function or class.  Put that function or class in a .py file that lives in `modules/`.  Import the module you made and use it to get your work done.  For reference see `get_raw()` which is inside `modules/get_data.py`.

# %% [markdown]
# #### VCT 2024 EDA
#
# Before doing EDA, it's important to define what we mean by win rate. Since the data does not explicitly have this data for us, we will have to do some feature engineering. Luckily, we have what we need to make these calculations. We will be calculating headshot percentages as a team and compare it to team win rates of a match.
#
# Then, we will look into agents and how their pick rates are distributed for the VCT 2024 season.

# %%
# create function that converts percent strings into float values

def convert_percent_column(series, as_proportion=False):
    """
    purpose: converts pandas Series like '64%' into numeric
    
    params:
        series (pd.Series): column containing percentage strings
        as_proportion (bool): if True, returns proportion as a decimal (e.g 0.64 instead of 64)
    
    returns:
        pd.Series (float)
    """
    cleaned_series = (series.astype(str).str.strip().str.replace('%', '', regex = False))
    
    # convert
    numeric = pd.to_numeric(cleaned_series, errors='coerce')  
    
    if as_proportion:
        numeric = numeric / 100
        
    return numeric

# %%
# convert percentages column from object into float data types
vct24_overview_clean['Headshot %'] = convert_percent_column(
    vct24_overview_clean['Headshot %'],
    as_proportion = True
)

# since we will eventually look into agent pick rate, we will also convert the 'Pick Rate' column here
vct24_agents_pick['Pick Rate'] = convert_percent_column(
    vct24_agents_pick['Pick Rate'],
    as_proportion = True
)

# %%
# calculate headshot percentage as a team
playoffs_overview = vct24_overview_clean[vct24_overview_clean['Stage'] == 'Playoffs']

playoffs_overview = (
    playoffs_overview
    .groupby('Team')['Headshot %']
    .mean()
    .reset_index(name = 'avg_team_hs')
)

print(playoffs_overview.shape)
playoffs_overview.head()
# Out:
# (31, 2)
#               Team  avg_team_hs
# 0      100 Thieves     0.275740
# 1       All Gamers     0.300000
# 2  Bilibili Gaming     0.256000
# 3           Cloud9     0.306000
# 4              DRX     0.283436

# %%
unique_teams = playoffs_overview['Team'].unique()
print(unique_teams)

num_unique_teams = playoffs_overview['Team'].nunique()
print('\nNumber of unique teams:', num_unique_teams)
# Out:
# ['100 Thieves' 'All Gamers' 'Bilibili Gaming' 'Cloud9' 'DRX'
#  'Dragon Ranger Gaming' 'EDward Gaming' 'Evil Geniuses' 'FNATIC'
#  'FUT Esports' 'FunPlus Phoenix' 'G2 Esports' 'Gen.G' 'JDG Esports'
#  'KRÜ Esports' 'Karmine Corp' 'LEVIATÁN' 'LOUD' 'NRG Esports'
#  'Natus Vincere' 'Nova Esports' 'Paper Rex' 'Rex Regum Qeon' 'Sentinels'
#  'T1' 'Talon Esports' 'Team Heretics' 'Team Liquid' 'Team Secret'
#  'Team Vitality' 'Trace Esports']
#
# Number of unique teams: 31

# %%
team_region_mapping = {

    # Americas
    "Evil Geniuses": "Americas",
    "LOUD": "Americas",
    "NRG Esports": "Americas",
    "Sentinels": "Americas",
    "100 Thieves": "Americas",
    "Cloud9": "Americas",
    "G2 Esports": "Americas",
    "KRÜ Esports": "Americas",
    "LEVIATÁN": "Americas",

    # EMEA
    "FNATIC": "EMEA",
    "Karmine Corp": "EMEA",
    "Natus Vincere": "EMEA",
    "Team Heretics": "EMEA",
    "FUT Esports": "EMEA",
    "Team Liquid": "EMEA",
    "Team Vitality": "EMEA",

    # Pacific
    "Gen.G": "Pacific",
    "Paper Rex": "Pacific",
    "DRX": "Pacific",
    "T1": "Pacific",
    "Talon Esports": "Pacific",
    "Team Secret": "Pacific",
    "Rex Regum Qeon": "Pacific",

    # China
    "Dragon Ranger Gaming": "China",
    "EDward Gaming": "China",
    "FunPlus Phoenix": "China",
    "Trace Esports": "China",
    "All Gamers": "China",
    "Nova Esports": "China",
    "Bilibili Gaming": "China",
    "JDG Esports": "China",
}

len(team_region_mapping)
# Out:
# 31

# %%
playoffs_overview['Team Region'] = playoffs_overview['Team'].map(team_region_mapping)
playoffs_overview
# Out:
#                     Team  avg_team_hs Team Region
# 0            100 Thieves     0.275740    Americas
# 1             All Gamers     0.300000       China
# 2        Bilibili Gaming     0.256000       China
# 3                 Cloud9     0.306000    Americas
# 4                    DRX     0.283436     Pacific
# 5   Dragon Ranger Gaming          NaN       China
# 6          EDward Gaming     0.291571       China
# 7          Evil Geniuses     0.307167    Americas
# 8                 FNATIC     0.273600        EMEA
# 9            FUT Esports     0.260098        EMEA
# 10       FunPlus Phoenix     0.327158       China
# 11            G2 Esports     0.257202    Americas
# 12                 Gen.G     0.277075     Pacific
# 13           JDG Esports     0.300667       China
# 14           KRÜ Esports     0.296444    Americas
# 15          Karmine Corp     0.301630        EMEA
# 16              LEVIATÁN     0.285130    Americas
# 17                  LOUD     0.273645    Americas
# 18           NRG Esports     0.280667    Americas
# 19         Natus Vincere     0.323267        EMEA
# 20          Nova Esports          NaN       China
# 21             Paper Rex     0.290582     Pacific
# 22        Rex Regum Qeon     0.319778     Pacific
# 23             Sentinels     0.256108    Americas
# 24                    T1     0.278863     Pacific
# 25         Talon Esports     0.315816     Pacific
# 26         Team Heretics     0.346916        EMEA
# 27           Team Liquid     0.315667        EMEA
# 28           Team Secret     0.274778     Pacific
# 29         Team Vitality     0.232381        EMEA
# 30         Trace Esports     0.255000       China

# %% [markdown]
# Now that we have calculated the average headshot rate per team, we need to calculate each team's win rate of a match.

# %%
# we will be using this dataframe to calcualte this!
vct24_scores.head()
# Out:
#                 Tournament        Stage   Match Type  \
# 0  Valorant Champions 2024  Group Stage  Opening (B)
# 1  Valorant Champions 2024  Group Stage  Opening (B)
# 2  Valorant Champions 2024  Group Stage  Opening (A)
# 3  Valorant Champions 2024  Group Stage  Opening (A)
# 4  Valorant Champions 2024  Group Stage  Opening (C)
#
#                          Match Name           Team A           Team B  \
# 0                Gen.G vs Sentinels            Gen.G        Sentinels
# 1  FunPlus Phoenix vs Team Heretics  FunPlus Phoenix    Team Heretics
# 2                DRX vs KRÜ Esports              DRX      KRÜ Esports
# 3         FNATIC vs Bilibili Gaming           FNATIC  Bilibili Gaming
# 4         LEVIATÁN vs Talon Esports         LEVIATÁN    Talon Esports
#
#    Team A Score  Team B Score       Match Result
# 0             2             0          Gen.G won
# 1             1             2  Team Heretics won
# 2             2             1            DRX won
# 3             2             0         FNATIC won
# 4             2             0       LEVIATÁN won

# %%
# calculate team win rate

# make long dataframe (one row per team per match)
playoffs_scores = vct24_scores[vct24_scores['Stage'] == 'Playoffs']
df = playoffs_scores.copy()

team_a = df[[
    "Tournament", "Stage", "Match Type",
    "Team A", "Match Result"
]].copy()

team_a.columns = [
    "Tournament", "Stage", "Match Type",
    "Team", "Match Result"
]

team_b = df[[
    "Tournament", "Stage", "Match Type",
    "Team B", "Match Result"
]].copy()

team_b.columns = [
    "Tournament", "Stage", "Match Type",
    "Team", "Match Result"
]

matches_long = pd.concat([team_a, team_b], ignore_index=True)

# determine who won the match
matches_long["Winner"] = matches_long["Match Result"].str.replace(
    " won", "", regex = False
)

matches_long["Win"] = (
    matches_long["Team"] == matches_long["Winner"]
).astype(int)

# aggregate to team level
team_record = (
    matches_long
    .groupby("Team")
    .agg(
        Matches_Played = ("Win", "count"),
        Wins = ("Win", "sum")
    )
    .reset_index()
)

team_record["Losses"] = (
    team_record["Matches_Played"] - team_record["Wins"]
)

team_record["Win Rate"] = (
    team_record["Wins"] / team_record["Matches_Played"]
)

team_record = team_record.sort_values("Win Rate", ascending = False)

print(team_record.shape)
team_record
# Out:
# (31, 5)
#                     Team  Matches_Played  Wins  Losses  Win Rate
# 12                 Gen.G              17    14       3  0.823529
# 6          EDward Gaming              15    12       3  0.800000
# 0            100 Thieves              11     7       4  0.636364
# 23             Sentinels              11     7       4  0.636364
# 26         Team Heretics              21    13       8  0.619048
# 29         Team Vitality               5     3       2  0.600000
# 8                 FNATIC              15     9       6  0.600000
# 10       FunPlus Phoenix               9     5       4  0.555556
# 16              LEVIATÁN              11     6       5  0.545455
# 21             Paper Rex              15     8       7  0.533333
# 11            G2 Esports              14     7       7  0.500000
# 24                    T1               5     2       3  0.400000
# 15          Karmine Corp               5     2       3  0.400000
# 5   Dragon Ranger Gaming               5     2       3  0.400000
# 2        Bilibili Gaming               3     1       2  0.333333
# 14           KRÜ Esports               6     2       4  0.333333
# 30         Trace Esports              10     3       7  0.300000
# 4                    DRX              10     3       7  0.300000
# 9            FUT Esports               8     2       6  0.250000
# 25         Talon Esports               4     1       3  0.250000
# 17                  LOUD               5     1       4  0.200000
# 28           Team Secret               2     0       2  0.000000
# 27           Team Liquid               1     0       1  0.000000
# 3                 Cloud9               2     0       2  0.000000
# 13           JDG Esports               1     0       1  0.000000
# 7          Evil Geniuses               1     0       1  0.000000
# 20          Nova Esports               1     0       1  0.000000
# 19         Natus Vincere               3     0       3  0.000000
# 18           NRG Esports               1     0       1  0.000000
# 1             All Gamers               2     0       2  0.000000
# 22        Rex Regum Qeon               1     0       1  0.000000

# %% [markdown]
# Great! We can now merge these dataframes together since it's easier to have everything in one place.

# %%
playoffs_teams_merged = pd.merge(playoffs_overview, team_record, on = 'Team', how = 'inner')

print(playoffs_teams_merged.shape)
playoffs_teams_merged
# Out:
# (31, 7)
#                     Team  avg_team_hs Team Region  Matches_Played  Wins  \
# 0            100 Thieves     0.275740    Americas              11     7
# 1             All Gamers     0.300000       China               2     0
# 2        Bilibili Gaming     0.256000       China               3     1
# 3                 Cloud9     0.306000    Americas               2     0
# 4                    DRX     0.283436     Pacific              10     3
# 5   Dragon Ranger Gaming          NaN       China               5     2
# 6          EDward Gaming     0.291571       China              15    12
# 7          Evil Geniuses     0.307167    Americas               1     0
# 8                 FNATIC     0.273600        EMEA              15     9
# 9            FUT Esports     0.260098        EMEA               8     2
# 10       FunPlus Phoenix     0.327158       China               9     5
# 11            G2 Esports     0.257202    Americas              14     7
# 12                 Gen.G     0.277075     Pacific              17    14
# 13           JDG Esports     0.300667       China               1     0
# 14           KRÜ Esports     0.296444    Americas               6     2
# 15          Karmine Corp     0.301630        EMEA               5     2
# 16              LEVIATÁN     0.285130    Americas              11     6
# 17                  LOUD     0.273645    Americas               5     1
# 18           NRG Esports     0.280667    Americas               1     0
# 19         Natus Vincere     0.323267        EMEA               3     0
# 20          Nova Esports          NaN       China               1     0
# 21             Paper Rex     0.290582     Pacific              15     8
# 22        Rex Regum Qeon     0.319778     Pacific               1     0
# 23             Sentinels     0.256108    Americas              11     7
# 24                    T1     0.278863     Pacific               5     2
# 25         Talon Esports     0.315816     Pacific               4     1
# 26         Team Heretics     0.346916        EMEA              21    13
# 27           Team Liquid     0.315667        EMEA               1     0
# 28           Team Secret     0.274778     Pacific               2     0
# 29         Team Vitality     0.232381        EMEA               5     3
# 30         Trace Esports     0.255000       China              10     3
#
#     Losses  Win Rate
# 0        4  0.636364
# 1        2  0.000000
# 2        2  0.333333
# 3        2  0.000000
# 4        7  0.300000
# 5        3  0.400000
# 6        3  0.800000
# 7        1  0.000000
# 8        6  0.600000
# 9        6  0.250000
# 10       4  0.555556
# 11       7  0.500000
# 12       3  0.823529
# 13       1  0.000000
# 14       4  0.333333
# 15       3  0.400000
# 16       5  0.545455
# 17       4  0.200000
# 18       1  0.000000
# 19       3  0.000000
# 20       1  0.000000
# 21       7  0.533333
# 22       1  0.000000
# 23       4  0.636364
# 24       3  0.400000
# 25       3  0.250000
# 26       8  0.619048
# 27       1  0.000000
# 28       2  0.000000
# 29       2  0.600000
# 30       7  0.300000

# %% [markdown]
# Now, we can try to visualize each team's average headshot percentage and their win rate of a match using a scatterplot.

# %%
fig = sns.regplot(playoffs_teams_merged, x = 'avg_team_hs', y = 'Win Rate', ci = None)
plt.title('How does average team headshot rate compare to their match win rate?')
plt.xlabel('Average team headshot rate')
plt.ylabel('Match win rate')
# Out:
# Text(0, 0.5, 'Match win rate')

# %% [markdown]
# Based on the scatterplot, it seems there is a weak, negative correlation between a team's average headshot rate and their match win rate. This is especially interesting to see since you would expect the chances of winning a match to increase if the team's headshot rate is high on average. Some outliers to point out here would be between the 0.28 and 0.30 headshot rate mark. While these headshot rates are low, these teams were able to have a high match win rate of around 0.8 or higher.

# %% [markdown]
# The next step is to see how agent pick rates are distributed throughout the Playoffs stage.

# %%
# filter by playoffs stage & all maps
playoffs_overall_agents_pick = vct24_agents_pick[(vct24_agents_pick['Stage'] == 'Playoffs') & (vct24_agents_pick['Map'] == 'All Maps')]

'''
procedure: 
1) find average pick rate per agent
2) sort in descending order
3) reset index so 'agent' is a column again
'''
playoffs_overall_agents_pick = playoffs_overall_agents_pick.groupby('Agent')[['Pick Rate']].mean().sort_values(by = 'Pick Rate', ascending = False).reset_index()

print(playoffs_overall_agents_pick.shape)
playoffs_overall_agents_pick.head()
# Out:
# (24, 2)
#     Agent  Pick Rate
# 0    omen   0.650260
# 1   viper   0.548442
# 2    raze   0.486494
# 3    sova   0.449091
# 4  cypher   0.417273

# %%
# plot agent & their respective pick rate
fig = sns.barplot(data = playoffs_overall_agents_pick, x = 'Pick Rate', y = 'Agent', errorbar = None)
plt.title('Playoffs Stage: Omen has highest pick rate across all maps')
# Out:
# Text(0.5, 1.0, 'Playoffs Stage: Omen has highest pick rate across all maps')

# %% [markdown]
# Here, we have generated a bar plot comparing each agent with their overall pick rate across all maps during the Playoffs stage. At first glance, we can see that the highest agent pick rate is Omen while the lowest pick rate is Iso. But what does this mean? To reiterate from earlier, a controller's utility kit helps manipulate site space while duelist's utility kit is known to help their team enter a site and take the first fights. So you might be wondering, why is Omen, a controller, picked more than Iso, a duelist?
#
# Since there are a lot of agents listed in the visualization, it may be easier to interpret pick rates categorized by role.

# %%
# categorizing agents by their role
role_mapping = {
    'reyna': 'duelist',
    'jett': 'duelist',
    'phoenix': 'duelist',
    'iso': 'duelist',
    'raze': 'duelist',
    'neon': 'duelist',
    'yoru': 'duelist',

    'omen': 'controller',
    'astra': 'controller',
    'brimstone': 'controller',
    'viper': 'controller',
    'harbor': 'controller',
    'clove': 'controller',
    
    'sova': 'initiator',
    'breach': 'initiator',
    'fade': 'initiator',
    'kayo': 'initiator',
    'gekko': 'initiator',
    'skye': 'initiator',

    'cypher': 'sentinel',
    'killjoy': 'sentinel',
    'sage': 'sentinel',
    'chamber': 'sentinel',
    'deadlock': 'sentinel'
}

len(role_mapping) # output: 24

# %% [markdown]
# You may be wondering why there are only 24 agents listed in this mapping when it was stated in the background section that there are 28 agents. The reason is that newer agents&mdash;Veto, Vyse, Tejo, Waylay&mdash;were released later in the year, so they were not a part of the VCT 2024 season.

# %%
# map roles to agents
playoffs_overall_agents_pick['Agent Role'] = playoffs_overall_agents_pick['Agent'].map(role_mapping)
playoffs_overall_agents_pick.head()

# %%
# filter so it's easier to plot by role
duelist_picks = playoffs_overall_agents_pick[playoffs_overall_agents_pick['Agent Role'] == 'duelist']
initiator_picks = playoffs_overall_agents_pick[playoffs_overall_agents_pick['Agent Role'] == 'initiator']
controller_picks = playoffs_overall_agents_pick[playoffs_overall_agents_pick['Agent Role'] == 'controller']
sentinel_picks = playoffs_overall_agents_pick[playoffs_overall_agents_pick['Agent Role'] == 'sentinel']

# %%
# create bar plots comparing agents & their respective pick rates, separated by their role
fig, axes = plt.subplots(2, 2, figsize = (16, 10))

# duelist
sns.barplot(
    data = duelist_picks.sort_values("Pick Rate", ascending = False),
    x = "Pick Rate",
    y = "Agent",
    errorbar = None,
    ax = axes[0, 0]
)
axes[0, 0].set_title("Duelist")

# initiator
sns.barplot(
    data = initiator_picks.sort_values("Pick Rate", ascending = False),
    x = "Pick Rate",
    y = "Agent",
    errorbar = None,
    ax = axes[0, 1]
)
axes[0, 1].set_title("Initiator")

# controller
sns.barplot(
    data = controller_picks.sort_values("Pick Rate", ascending = False),
    x = "Pick Rate",
    y = "Agent",
    errorbar = None,
    ax = axes[1, 0]
)
axes[1, 0].set_title("Controller")

# sentinel
sns.barplot(
    data = sentinel_picks.sort_values("Pick Rate", ascending = False),
    x = "Pick Rate",
    y = "Agent",
    errorbar = None,
    ax = axes[1, 1]
)
axes[1, 1].set_title("Sentinel")

plt.suptitle("Playoffs Stage: Overall Agent Pick Rate Across All Maps by Role", fontsize = 16)
plt.tight_layout()
plt.show()

# %% [markdown]
# When we think about the question we asked earlier, "why is Omen, a controller, picked more than Iso, a duelist?", it is also important to consider the distribution of roles in a team.
#
# A typical team composition may involve at least one agent from each role. Since there are four roles, it is easy to satisfy this type of composition and the last person's role can be flexible, which is why sometimes there may be two people playing the same role in a team. However, there are other instances where a team might play a composition of two duelists, two controllers, and one initiator, meaning that no one is playing a sentinel role for example. Of course, there are many variations.
#
# Going back to the question, the answer may simply be that Omen's utility provides more value to the team than Iso, and that a different duelist is picked instead.
#
# You might also wonder, can Omen and Iso both be picked for one team? The answer is yes, but that may depend on other agents that are picked for the team and also the map that is being played.

# %%
team_hs_region = playoffs_overview.copy()
team_hs_region = team_hs_region.dropna(subset=['avg_team_hs'])

plt.figure(figsize=(10, 6))
colors = {'Americas': 'red', 'EMEA': 'blue', 'Pacific': 'green', 'China': 'orange'}
sns.boxplot(data=team_hs_region, x='Team Region', y='avg_team_hs', 
            hue='Team Region', palette=list(colors.values()), legend=False)
sns.stripplot(data=team_hs_region, x='Team Region', y='avg_team_hs',
              color='black', alpha=0.5, size=8, jitter=True)
plt.title('Headshot % Distribution by Region - VCT 2024 Playoffs')
plt.xlabel('Region')
plt.ylabel('Average Headshot %')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Boxplot - Headshot % Distribution by Region VCT 2024 Playoffs
# This boxplot shows the distribution of headshot percentage across the 4 regions (31 teams) that played in playoffs. Each box represents the middle 50% of that region and the middle line is the median. Each dot represents a team from that region.
#
# #### Observations
# - Americas (NA): This box appears to be tied with APAC for the smallest and lowest median. This means, the majority of players have very similar headshot percentages. The only difference is, Americas distribution is a bit wider and on the lower end.
# - China: This box is the second largest box and is also the second widest distribution next to EMEA. This box is unique as the median is very close to the end of the upper quartile.
# - Pacific (APAC): APAC's boxplot has the thinnest distribution meaning everyones headshot percentage is most similar in this region.
# - EMEA: EMEA's boxplot is the largest. Everyone's headshot percentage is vastly different from each other. If we look at the dots, all of them are a decent length apart. Every other region looks like at least one of their dots almost overlap.

# %%
team_wr_region = playoffs_teams_merged.copy()

plt.figure(figsize=(10, 6))

colors = {'Americas': 'red', 'EMEA': 'blue', 'Pacific': 'green', 'China': 'orange'}

sns.boxplot(
    data = team_wr_region, x = 'Team Region', y = 'Win Rate',
    hue = 'Team Region', palette = list(colors.values()), legend = False
)
sns.stripplot(
    data = team_wr_region, x = 'Team Region', y = 'Win Rate',
    color = 'black', alpha = 0.5, size = 8, jitter = True
)

plt.title('Win Rate % Distribution by Region - VCT 2024 Playoffs')
plt.xlabel('Region')
plt.ylabel('Win Rate %')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Boxplot - Win Rate Distribution by Region VCT 2024 Playoffs
# This boxplot shows the distribution of win rate percentage across the 4 regions that played in playoffs. Each box represents the middle 50% of that region and the middle line is the median. Each dot represents a team from that region.
#
# #### Observations
# - Americas (NA): This box doesn't seem to match the headshot percentage box much, it has the biggest shift in terms of distribution (from most similar in headshot % to biggest gap in win rate %). In general, this region's win rate has the widest range compared to the other regions despite having
# the smallest range when it came to headshot percentage where it was neither worst or best (but could be considered worst if only looking at all regions' max headshot %).
# However, in this boxplot, we can see NA matches for worst at its lowest and for second best at its highest.
# - China: This box, when compared with the Pacific region, match their headshot counterpart a bit better. China has a wider range than Pacific in both, its lowest for both is noticeably worse
# than the pacific region's, and their highest is still slightly worse than the Pacific's best.
# - Pacific (APAC): As stated in China's observation, when compared, it's quite similar to the headshot boxplot. However, there are still a few differences, especially as despite having the thinnest
# distribution in headshots, and while still having the smallest range here, the distribution found here is still considerably larger compared to headshot distribution. You can also note                      that where they had their lowest headshot percentage be considerably better than EMEA's headshot percentage, their lowest win rate percentage here is tied with EMEA's lowest.
# - EMEA: EMEA here once again has their box's highest above that of the other region's. It, however, isn't the one with most distribution this time. Despite this, it's median still remains noticeably higher than the others, and in terms of lowest it's tied with Pacific, and both are considerably higher than both America's and China's tied lowest.
#
# Overall, comparing this to headshot %, the data shows us that there's some disconnect between who can more consistently get headshots and who wins. While the Americas is the most consistent region in headshot accuracy, that doesn't translate to win rate, as they suffer from the widest gap between their top and bottom-performing teams. On the other end, EMEA stands out as the most successful region, maintaining the highest median win rate and the highest win rate despite having the widest gap in terms of headshot percentage. It just ultimately shows that while aim can help provide an advantage or factor in terms of a victory, there's other potential factors (clutches, economy, team strategies/utility, or just generally more consistent mechanics) that should also be considered when looking into a
# team's winrate.

# %% [markdown]
# As a player, it is natural to wonder why certain agents are most frequently selected in professional play and whether higher pick rates are associated with stronger headshot percentages. In the following analysis, we examine both the popularity of agents and their performance distribution to better understand the relationship between the competitive meta and player-level performance trends.

# %%
agents_pick_rates = pd.read_csv("data/02-processed/vct_both_2024_2025/vct_2024/agents_pick.csv")
players_stats = pd.read_csv("data/02-processed/vct_both_2024_2025/vct_2024/players_stats.csv")

# %%
agents_pick_rates['Pick Rate'] = (
    agents_pick_rates['Pick Rate']
    .str.replace('%','')
    .astype(float)
)

# %%
# Compute the top 10 agents based on their average pick rate
top_pick = (
    agents_pick_rates
    .groupby('Agent')['Pick Rate']
    .mean()
    .sort_values(ascending=False)
    .head(10)
)

# %%
# Bar chart shows the most frequently selected agents
plt.figure(figsize=(10,6))
top_pick.plot(kind='bar')

plt.title("Top 10 Agents by Average Pick Rate")
plt.ylabel("Pick Rate (%)")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# The barplot shows the top 10 agents ranked by their average pick rate in professional VCT matches. As we can see, Omen and Viper have the highest pick rates, which suggests that they are highly favored in the current competitive meta. Of course, other agents such as Raze, Sova, and Cypher are also commonly selected in professional play.
#
# As players, this makes us wonder why these agents dominate the meta. Is it because of their abilities, team utility, or are there other reasons behind their popularity?

# %%
players_stats['Headshot %'] = (
    players_stats['Headshot %']
    .str.replace('%','')
    .astype(float)
)

# %%
#Identify the 10 most frequently played agents
top_agents = (
    players_stats['Agents']
    .value_counts()
    .head(10)
    .index
)

filtered = players_stats[
    players_stats['Agents'].isin(top_agents)
]

# %%
# create the distribution of headshot percentage
# for the top 10 most played agents
plt.figure(figsize=(12,6))

sns.boxplot(
    data=filtered,
    x='Agents',
    y='Headshot %',
    hue='Agents',      
    palette='Set2',
    legend=False       
)

plt.xticks(rotation=45)
plt.title("Headshot % Distribution by Top 10 Agents")
plt.show()

# %% [markdown]
# This boxplot shows the distribution of headshot percentages for the top 10 most frequently picked agents. Most agents have median headshot percentages around the 20% to 30% range. Interestingly, the distributions look fairly similar across agents, although some agents display slightly wider variability. This suggests that headshot percentage does not differ dramatically across these agents. Therefore, higher pick rates may not necessarily correspond to higher headshot accuracy.
#
# If headshot accuracy is similar across agents, perhaps agent popularity is influenced more by team strategy and utility rather than raw aim.
#
# These observations indicate that while certain agents dominate the professional meta in terms of selection frequency, agent popularity may not necessarily be driven by headshot percentage alone but could also depend on team strategy, utility value, or map-specific advantages.

# %% [markdown]
# #### VCT 2025 EDA
#
# Some more words and stuff.  Remember notebooks work best if you interleave the code that generates a result with properly annotate figures and text that puts these results into context.

# %%
## YOUR CODE HERE
## FEEL FREE TO ADD MULTIPLE CELLS PER SECTION

# %% [markdown]
# ## Ethics
#
# Instructions: Keep the contents of this cell. For each item on the checklist
# -  put an X there if you've considered the item
# -  IF THE ITEM IS RELEVANT place a short paragraph after the checklist item discussing the issue.
#
# Items on this checklist are meant to provoke discussion among good-faith actors who take their ethical responsibilities seriously. Your teams will document these discussions and decisions for posterity using this section.  You don't have to solve these problems, you just have to acknowledge any potential harm no matter how unlikely.
#
# Here is a [list of real world examples](https://deon.drivendata.org/examples/) for each item in the checklist that can refer to.
#
# [![Deon badge](https://img.shields.io/badge/ethics%20checklist-deon-brightgreen.svg?style=popout-square)](http://deon.drivendata.org/)
#
# ### A. Data Collection
#  - [ ] **A.1 Informed consent**: If there are human subjects, have they given informed consent, where subjects affirmatively opt-in and have a clear understanding of the data uses to which they consent?
#
# <!-- > Example of how to use the checkbox, and also of how you can put in a short paragraph that discusses the way this checklist item affects your project.  Remove this paragraph and the X in the checkbox before you fill this out for your project -->
#
#  - [X] **A.2 Collection bias**: Have we considered sources of bias that could be introduced during data collection and survey design and taken steps to mitigate those?
#
#  > From the Kaggle website of the first dataset we listed, the author was stated that some of the China stats are missing because Chinese hosted events do not have APIs available for post-game stats. This may lead to underrepresentation from Chinese teams and bias our findings towards patterns from the other regions. To combat this limitation, we will avoid making strong claims about China where data is missing.
#
#  - [X] **A.3 Limit PII exposure**: Have we considered ways to minimize exposure of personally identifiable information (PII) for example through anonymization or not collecting information that isn't relevant for analysis?
#
#  > While the dataset contains publicly available professional player names, we will not link their player profile to their private identities as they are not needed for analyses. We will focus more on teams as a whole rather than looking at each player individually.
#
#  - [ ] **A.4 Downstream bias mitigation**: Have we considered ways to enable testing downstream results for biased outcomes (e.g., collecting data on protected group status like race or gender)?
#
# ### B. Data Storage
#  - [ ] **B.1 Data security**: Do we have a plan to protect and secure data (e.g., encryption at rest and in transit, access controls on internal users and third parties, access logs, and up-to-date software)?
#  - [ ] **B.2 Right to be forgotten**: Do we have a mechanism through which an individual can request their personal information be removed?
#  - [ ] **B.3 Data retention plan**: Is there a schedule or plan to delete the data after it is no longer needed?
#
# ### C. Analysis
#  - [ ] **C.1 Missing perspectives**: Have we sought to address blindspots in the analysis through engagement with relevant stakeholders (e.g., checking assumptions and discussing implications with affected communities and subject matter experts)?
#  - [X] **C.2 Dataset bias**: Have we examined the data for possible sources of bias and taken steps to mitigate or address these biases (e.g., stereotype perpetuation, confirmation bias, imbalanced classes, or omitted confounding variables)?
#
#  > From the Kaggle website of the first dataset we listed, the author has also noted that the dataset contains missing values, placeholder team names, and inconsistencies such as two teams having the same team ID. As mentioned earlier, China has missing statistics as APIs are not publicly available. We plan to document any missing data we find and exclude rows where missing values are present.
#
#  - [X] **C.3 Honest representation**: Are our visualizations, summary statistics, and reports designed to honestly represent the underlying data?
#
#  > We plan to clearly label visualizations and document any uncertainties we come across to avoid strong conclusions. For example, if there are regional differences between the Americas and China, we will make sure to clarify whether the statement was based on complete or incomplete data.
#
#  - [ ] **C.4 Privacy in analysis**: Have we ensured that data with PII are not used or displayed unless necessary for the analysis?
#  - [X] **C.5 Auditability**: Is the process of generating the analysis well documented and reproducible if we discover issues in the future?
#
#  > When performing data analysis and cleaning, we will make sure our code is well-documented so that others can easily follow along and reproduce our results. For example, since we will be looking at VCT playoff games for the years 2024 and 2025, we will clearly state these filtering decisions.
#
# ### D. Modeling
#  - [ ] **D.1 Proxy discrimination**: Have we ensured that the model does not rely on variables or proxies for variables that are unfairly discriminatory?
#  - [ ] **D.2 Fairness across groups**: Have we tested model results for fairness with respect to different affected groups (e.g., tested for disparate error rates)?
#  - [ ] **D.3 Metric selection**: Have we considered the effects of optimizing for our defined metrics and considered additional metrics?
#  - [ ] **D.4 Explainability**: Can we explain in understandable terms a decision the model made in cases where a justification is needed?
#  - [ ] **D.5 Communicate limitations**: Have we communicated the shortcomings, limitations, and biases of the model to relevant stakeholders in ways that can be generally understood?
#
# ### E. Deployment
#  - [ ] **E.1 Monitoring and evaluation**: Do we have a clear plan to monitor the model and its impacts after it is deployed (e.g., performance monitoring, regular audit of sample predictions, human review of high-stakes decisions, reviewing downstream impacts of errors or low-confidence decisions, testing for concept drift)?
#  - [ ] **E.2 Redress**: Have we discussed with our organization a plan for response if users are harmed by the results (e.g., how does the data science team evaluate these cases and update analysis and models to prevent future harm)?
#  - [ ] **E.3 Roll back**: Is there a way to turn off or roll back the model in production if necessary?
#  - [ ] **E.4 Unintended use**: Have we taken steps to identify and prevent unintended uses and abuse of the model and do we have a plan to monitor these once the model is deployed?

# %% [markdown]
# ## Team Expectations

# %% [markdown]
# - Communication
#     - Discord will be used as the main form of communication and we will either meet in person or online every week
#     - If you're struggling with a task, don't hesitate to ask others for help
# - Tone
#     - Be respectful, patient, and friendly towards each other
# - Decision making
#     - If pushing to the main branch, announce it to the group first just in case anyone else is working on it at the same time
# - Tasks
#     - Work will be discussed and divided equally among members
#     - Everyone is expected to contribute equally to coding, writing, etc., and to meet deadlines on time
#     - Have reminders of deadlines accordingly with our timeline
# - Conflicts
#     - We will first discuss issues calmly within the group, and if it cannot be resolved, we will ask the professor or TAs for help

# %% [markdown]
# ## Project Timeline Proposal

# %% [markdown]
# | Meeting Date  | Meeting Time| Completed Before Meeting  | Discuss at Meeting |
# |---|---|---|---|
# | 2/1  | 5 PM  | Brainstorm & search for potential datasets  | Draft project proposal, assign roles   |
# | 2/8  | 5 PM  | Do background research on topic   | Discuss data wrangling approaches, split work evenly |
# | 2/16  | 5 PM  | Import & wrangle data | Complete data wrangling checkpoint, and revise background, hypothesis, and research question |
# | 2/22  | 5 PM  | Note ideas for EDA checkpoint | Split and start EDA work between members |
# | 3/1   | 5 PM  | Finalize EDA and discuss analysis plan | Split and start analysis work between members |
# | 3/8   | 5 PM  | Complete analysis; begin results, conclusion, and discussion | Finalize group project, split presentation slides across team members |
# | 3/16  | Before 11:59 PM  | Complete final project notebook & video presentation | Turn in final project, video presentation, & group project surveys |
